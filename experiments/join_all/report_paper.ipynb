# %%
import os;
import json;
import builtins
import duckdb
import pandas as pd;
import matplotlib.pyplot as plt

def get_dataset_from_testcase(run):
    return run[0:-2]

dirs = [
    '/home/chesetti/Repos/learned_merge_cleanup/old_results/sponge_paper/join_all',
]
runs = []
for dir in dirs:
 for test_case in os.listdir(dir):
    if test_case == 'build':
        continue
    for run_name in os.listdir(os.path.join(dir, test_case, 'outputs', 'results')):
        if (run_name=="run"):
           continue
        json_file = builtins.open(os.path.join(dir, test_case, 'outputs', 'results',  run_name))
        run = (json.load(json_file))
        run['dataset'] = get_dataset_from_testcase(test_case)
        runs.append(run)
    for run_name in os.listdir(os.path.join(dir, test_case, 'outputs', 'results', 'run')):
        json_file = builtins.open(os.path.join(dir, test_case, 'outputs', 'results', 'run', run_name))
        run = (json.load(json_file))
        run['dataset'] = get_dataset_from_testcase(test_case)
        runs.append(run)
df = pd.json_normalize(runs)
print(df.columns)
display(df)
# Out:
# Index(['command', 'dataset', 'result.checksum', 'result.duration_ns',
#        'result.duration_sec', 'result.inner_disk_fetch',
#        'result.inner_disk_fetch_size', 'result.inner_total_bytes_fetched',
#        'result.num_output_keys', 'result.outer_disk_fetch',
#        'result.outer_disk_fetch_size', 'result.outer_total_bytes_fetched',
#        'spec.algo', 'spec.algo_name', 'spec.check_checksum', 'spec.common_key',
#        'spec.index.epsilon', 'spec.index.search', 'spec.index.type',
#        'spec.inner_table', 'spec.key_size', 'spec.key_type',
#        'spec.load_sstable_in_mem', 'spec.name', 'spec.num_threads',
#        'spec.outer_table', 'spec.result_path', 'spec.value_size',
#        'spec.write_result_to_disk', 'spec.index.leaf_size_in_pages'],
#       dtype='object')
#                                                 command dataset  \
# 0     numactl -N 1 -m 1 sponge/join_all/build/benchm...      fb
# 1     numactl -N 1 -m 1 sponge/join_all/build/benchm...      fb
# 2     numactl -N 1 -m 1 sponge/join_all/build/benchm...      fb
# 3     numactl -N 1 -m 1 sponge/join_all/build/benchm...      fb
# 4     numactl -N 1 -m 1 sponge/join_all/build/benchm...      fb
# ...                                                 ...     ...
# 2483  numactl -N 1 -m 1 sponge/join_all/build/benchm...    wiki
# 2484  numactl -N 1 -m 1 sponge/join_all/build/benchm...    wiki
# 2485  numactl -N 1 -m 1 sponge/join_all/build/benchm...    wiki
# 2486  numactl -N 1 -m 1 sponge/join_all/build/benchm...    wiki
# 2487  numactl -N 1 -m 1 sponge/join_all/build/benchm...    wiki
#
#                        result.checksum  result.duration_ns  \
# 0     37FC5C182B197FF06811E9D7701E605F           926487305
# 1     90821B94D6A6E903EBEC6EA236EB68A2           793160900
# 2     37FC5C182B197FF06811E9D7701E605F          1481070595
# 3     972CC95E6631904D8287EE4B23FBE0F1          5365979627
# 4     37FC5C182B197FF06811E9D7701E605F          1621758665
# ...                                ...                 ...
# 2483  985AD79CA52B42BBF980947E772AC147           649332115
# 2484  C6E2640CC75B5FBEC2A3BBADE5D387EB         23636991757
# 2485  80A82214F3DC31463C732262E3CFA6B1          4416750025
# 2486  80A82214F3DC31463C732262E3CFA6B1          4059837048
# 2487  80A82214F3DC31463C732262E3CFA6B1          3799675004
#
#       result.duration_sec  result.inner_disk_fetch  \
# 0                0.926487                   386314
# 1                0.793161                    85590
# 2                1.481071                    48829
# 3                5.365980                   317998
# 4                1.621759                   405012
# ...                   ...                      ...
# 2483             0.649332                    20781
# 2484            23.636992                   353270
# 2485             4.416750                    20781
# 2486             4.059837                   119781
# 2487             3.799675                   119781
#
#       result.inner_disk_fetch_size  result.inner_total_bytes_fetched  \
# 0                             8192                        3164684288
# 1                            69632                        5959802880
# 2                            65536                        3199999984
# 3                            69632                       22142752720
# 4                            20480                        8294627280
# ...                            ...                               ...
# 2483                         69632                        1446975792
# 2484                          4096                        1446992176
# 2485                         69632                        1446990624
# 2486                         69632                        8340448368
# 2487                         69632                        8340448368
#
#       result.num_output_keys  result.outer_disk_fetch  ...  spec.key_size  \
# 0                    1989990                     7774  ...              8
# 1                     199913                      781  ...              8
# 2                    1989990                     7774  ...              8
# 3                   19031039                    74340  ...              8
# 4                    1989990                     7774  ...              8
# ...                      ...                      ...  ...            ...
# 2483                 1968997                     7692  ...              8
# 2484                90437011                   353270  ...              8
# 2485                17262484                    67432  ...              8
# 2486                17262484                    67432  ...              8
# 2487                17262484                    67432  ...              8
#
#       spec.key_type spec.load_sstable_in_mem                       spec.name  \
# 0            uint64                    False   lsj_sampledflatpgm256100run_2
# 1            uint64                    False       inlj_flatpgm40961000run_0
# 2            uint64                    False           lsj_btree4096100run_1
# 3            uint64                    False  inlj_sampledflatpgm409610run_0
# 4            uint64                    False        inlj_flatpgm1024100run_0
# ...             ...                      ...                             ...
# 2483         uint64                    False  lsj_sampledflatpgm4096100run_2
# 2484         uint64                    False             inlj_btree2561run_0
# 2485         uint64                    False              lsj_pgm409610run_0
# 2486         uint64                    False             inlj_pgm409610run_1
# 2487         uint64                    False         inlj_flatpgm409610run_1
#
#       spec.num_threads                        spec.outer_table  \
# 0                    1    sponge/join_all/fb_1/inputs/input100
# 1                    1   sponge/join_all/fb_1/inputs/input1000
# 2                    1    sponge/join_all/fb_1/inputs/input100
# 3                    1     sponge/join_all/fb_1/inputs/input10
# 4                    1    sponge/join_all/fb_1/inputs/input100
# ...                ...                                     ...
# 2483                 1  sponge/join_all/wiki_1/inputs/input100
# 2484                 1    sponge/join_all/wiki_1/inputs/input1
# 2485                 1   sponge/join_all/wiki_1/inputs/input10
# 2486                 1   sponge/join_all/wiki_1/inputs/input10
# 2487                 1   sponge/join_all/wiki_1/inputs/input10
#
#                                        spec.result_path spec.value_size  \
# 0     sponge/join_all/fb_1/outputs/lsj_sampledflatpg...               8
# 1     sponge/join_all/fb_1/outputs/inlj_flatpgm4096_...               8
# 2     sponge/join_all/fb_1/outputs/lsj_btree4096_run...               8
# 3     sponge/join_all/fb_1/outputs/inlj_sampledflatp...               8
# 4     sponge/join_all/fb_1/outputs/inlj_flatpgm1024_...               8
# ...                                                 ...             ...
# 2483  sponge/join_all/wiki_1/outputs/lsj_sampledflat...               8
# 2484  sponge/join_all/wiki_1/outputs/inlj_btree256_r...               8
# 2485  sponge/join_all/wiki_1/outputs/lsj_pgm4096_run...               8
# 2486  sponge/join_all/wiki_1/outputs/inlj_pgm4096_ru...               8
# 2487  sponge/join_all/wiki_1/outputs/inlj_flatpgm409...               8
#
#      spec.write_result_to_disk spec.index.leaf_size_in_pages
# 0                         True                           NaN
# 1                         True                           NaN
# 2                         True                          16.0
# 3                         True                           NaN
# 4                         True                           NaN
# ...                        ...                           ...
# 2483                      True                           NaN
# 2484                      True                           1.0
# 2485                      True                           NaN
# 2486                      True                           NaN
# 2487                      True                           NaN
#
# [2488 rows x 30 columns]

# %%
epsilon = {
    "pgm256": 256,
    "pgm1024": 1024,
    "pgm2048": 2048,
    "flatpgm256": 256,
    "flatpgm1024": 1024,
    "flatpgm2048": 2048,
    "flatpgm4096": 4096,
    "flatpgm8192": 8192,
    "hashjoin": 0,
    "btree": 0,
    "sj": 0,
    "sj2": 0,
    "standard_merge": 0
};
def indexType(x):
    if "pgm" in x:
        return "PGM"
    elif "btree" in x:
        return "BTREE"
    return "NA"

df["threads"] = df["spec.num_threads"]
df["duration_sec"] = df["result.duration_ns"] / (1000000000)
df["inner_disk_fetch"] = df["result.inner_disk_fetch"]
df['result_num_keys'] = df['result.num_output_keys']
df["ratio"] = df["spec.common_key"]
df["algo"] = df["spec.algo_name"]
df["epsilon"] = df["spec.index.epsilon"]
df["inner_bytes_fetched"] = df["result.inner_total_bytes_fetched"]
df["index_type"] = df["spec.algo_name"].map(lambda x: indexType(x))
df['dataset'].unique()
df['result.num_output_keys'].unique()
duckdb.sql("SELECT * FROM df WHERE dataset='fb'")
# Out:
# ┌──────────────────────┬─────────┬──────────────────────┬───┬─────────┬─────────────────────┬────────────┐
# │       command        │ dataset │   result.checksum    │ … │ epsilon │ inner_bytes_fetched │ index_type │
# │       varchar        │ varchar │       varchar        │   │ double  │        int64        │  varchar   │
# ├──────────────────────┼─────────┼──────────────────────┼───┼─────────┼─────────────────────┼────────────┤
# │ numactl -N 1 -m 1 …  │ fb      │ 37FC5C182B197FF068…  │ … │   256.0 │          3164684288 │ PGM        │
# │ numactl -N 1 -m 1 …  │ fb      │ 90821B94D6A6E903EB…  │ … │  4096.0 │          5959802880 │ PGM        │
# │ numactl -N 1 -m 1 …  │ fb      │ 37FC5C182B197FF068…  │ … │  4096.0 │          3199999984 │ BTREE      │
# │ numactl -N 1 -m 1 …  │ fb      │ 972CC95E6631904D82…  │ … │  4096.0 │         22142752720 │ PGM        │
# │ numactl -N 1 -m 1 …  │ fb      │ 37FC5C182B197FF068…  │ … │  1024.0 │          8294627280 │ PGM        │
# │ numactl -N 1 -m 1 …  │ fb      │ 90821B94D6A6E903EB…  │ … │    NULL │          3199999984 │ NA         │
# │ numactl -N 1 -m 1 …  │ fb      │ 972CC95E6631904D82…  │ … │  4096.0 │         15454316112 │ PGM        │
# │ numactl -N 1 -m 1 …  │ fb      │ 37FC5C182B197FF068…  │ … │  4096.0 │         16261552096 │ PGM        │
# │ numactl -N 1 -m 1 …  │ fb      │ 972CC95E6631904D82…  │ … │    NULL │          3199999984 │ NA         │
# │ numactl -N 1 -m 1 …  │ fb      │ 37FC5C182B197FF068…  │ … │  1024.0 │          8294627280 │ PGM        │
# │          ·           │ ·       │          ·           │ · │     ·   │               ·     │  ·         │
# │          ·           │ ·       │          ·           │ · │     ·   │               ·     │  ·         │
# │          ·           │ ·       │          ·           │ · │     ·   │               ·     │  ·         │
# │ numactl -N 1 -m 1 …  │ fb      │ 37FC5C182B197FF068…  │ … │   256.0 │          3164684288 │ PGM        │
# │ numactl -N 1 -m 1 …  │ fb      │ 90821B94D6A6E903EB…  │ … │  4096.0 │          3088388096 │ PGM        │
# │ numactl -N 1 -m 1 …  │ fb      │ 197D7E88032185A864…  │ … │  4096.0 │         44697462736 │ PGM        │
# │ numactl -N 1 -m 1 …  │ fb      │ 90821B94D6A6E903EB…  │ … │  4096.0 │          3062136832 │ PGM        │
# │ numactl -N 1 -m 1 …  │ fb      │ 90821B94D6A6E903EB…  │ … │   256.0 │          1195606016 │ PGM        │
# │ numactl -N 1 -m 1 …  │ fb      │ 37FC5C182B197FF068…  │ … │  4096.0 │          3199918064 │ PGM        │
# │ numactl -N 1 -m 1 …  │ fb      │ 197D7E88032185A864…  │ … │   256.0 │          3199999984 │ BTREE      │
# │ numactl -N 1 -m 1 …  │ fb      │ 972CC95E6631904D82…  │ … │  4096.0 │          3199998768 │ PGM        │
# │ numactl -N 1 -m 1 …  │ fb      │ 972CC95E6631904D82…  │ … │  4096.0 │         15454316112 │ PGM        │
# │ numactl -N 1 -m 1 …  │ fb      │ 972CC95E6631904D82…  │ … │  4096.0 │         15454316112 │ PGM        │
# ├──────────────────────┴─────────┴──────────────────────┴───┴─────────┴─────────────────────┴────────────┤
# │ 312 rows (20 shown)                                                               39 columns (6 shown) │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='256') AND dataset='fb'"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='256') AND dataset='fb'"
    " AND (algo='lsj_pgm256' OR algo='lsj_flatpgm256' OR algo='lsj_sampledpgm256' OR algo='lsj_sampledflatpgm256')"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='1024') AND dataset='wiki'"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='256') AND dataset='wiki'"
    " AND (algo='lsj_pgm256' OR algo='lsj_flatpgm256' OR algo='lsj_sampledpgm256' OR algo='lsj_sampledflatpgm256')"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='4096') AND dataset='books'"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='256') AND dataset='osm'"
    " AND (algo='lsj_pgm256' OR algo='lsj_flatpgm256' OR algo='lsj_sampledpgm256' OR algo='lsj_sampledflatpgm256')"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

# %%
rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(inner_disk_fetch) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='256') AND dataset='wiki'"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(inner_disk_fetch) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='1024') AND dataset='wiki'"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(inner_disk_fetch) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='4096') AND dataset='wiki'"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

# %%
def print_for_dataset(dataset, algos):
    print("## " + dataset)
    algo_filter = ''
    for algo in algos:
        algo_filter = algo_filter + f" OR algo='{algo}'"
    algo_filter = algo_filter[3:]
    rows = duckdb.sql(
        " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
        f" WHERE threads=1  AND dataset='{dataset}'"
        f" AND ({algo_filter})"
        " GROUP BY dataset, threads, ratio, algo"
        " ORDER BY ratio, threads"
    ).df()
    rows = rows.pivot(index='ratio', values='v', columns='algo')
    print(rows[algos].to_markdown())



algos = ['lsj_sampledflatpgm256', 'lsj_flatpgm256', 'lsj_pgm256', 'lsj_btree256', 'sort_join']
print_for_dataset("fb", algos)
print_for_dataset("wiki", algos)
print_for_dataset("osm", algos)
print_for_dataset("books", algos)
# Out:
# ## fb
# |   ratio |   lsj_sampledflatpgm256 |   lsj_flatpgm256 |   lsj_pgm256 |   lsj_btree256 |   sort_join |
# |--------:|------------------------:|-----------------:|-------------:|---------------:|------------:|
# |       1 |               27.3887   |        25.9765   |    32.3699   |      47.774    |    15.9073  |
# |      10 |                3.82759  |         4.07551  |     4.98752  |       6.49511  |     4.82552 |
# |     100 |                0.911438 |         1.19944  |     0.960022 |       1.63421  |     3.3648  |
# |    1000 |                0.309895 |         0.285341 |     0.356856 |       0.315716 |     3.17695 |
# ## wiki
# |   ratio |   lsj_sampledflatpgm256 |   lsj_flatpgm256 |   lsj_pgm256 |   lsj_btree256 |   sort_join |
# |--------:|------------------------:|-----------------:|-------------:|---------------:|------------:|
# |       1 |               12.4759   |        11.6909   |    13.7186   |      20.8463   |     6.96919 |
# |      10 |                3.15346  |         3.50702  |     3.42026  |       4.94191  |     2.79561 |
# |     100 |                0.634182 |         0.615757 |     0.658492 |       0.882262 |     1.42226 |
# |    1000 |                0.241131 |         0.216568 |     0.22496  |       0.22221  |     1.24528 |
# ## osm
# |   ratio |   lsj_sampledflatpgm256 |   lsj_flatpgm256 |   lsj_pgm256 |   lsj_btree256 |   sort_join |
# |--------:|------------------------:|-----------------:|-------------:|---------------:|------------:|
# |       1 |               109.234   |       103.677    |    138.027   |     200.463    |     65.1368 |
# |      10 |                15.1028  |        14.5773   |     18.5379  |      24.9458   |     16.7331 |
# |     100 |                 3.8559  |         3.35366  |      3.88908 |       5.16924  |     11.2683 |
# |    1000 |                 1.38973 |         0.987858 |      1.05577 |       0.917966 |     10.9971 |
# ## books
# |   ratio |   lsj_sampledflatpgm256 |   lsj_flatpgm256 |   lsj_pgm256 |   lsj_btree256 |   sort_join |
# |--------:|------------------------:|-----------------:|-------------:|---------------:|------------:|
# |       1 |                109.378  |        104.705   |    125.694   |      196.788   |     65.1045 |
# |      10 |                 15.1015 |         15.1598  |     17.3225  |       24.2808  |     17.8226 |
# |     100 |                  3.4583 |          3.71443 |      3.98957 |        5.06725 |     11.73   |
# |    1000 |                  1.3264 |          1.21456 |      1.03199 |        1.06479 |     11.3618 |

# %%
algos = ['lsj_sampledflatpgm256', 'lsj_pgm256', 'lsj_radixspline256', 'lsj_rmi' ]
print_for_dataset("fb", algos)
print_for_dataset("wiki", ['lsj_sampledflatpgm256', 'lsj_pgm256', 'lsj_radixspline256'])
print_for_dataset("osm", algos)
print_for_dataset("books", algos)

# %%
algos = ['lsj_radixspline256', 'lsj_radixspline1024', 'lsj_radixspline4096']
print_for_dataset("fb", algos)
print_for_dataset("wiki", algos)
print_for_dataset("osm", algos)
print_for_dataset("books", algos)
