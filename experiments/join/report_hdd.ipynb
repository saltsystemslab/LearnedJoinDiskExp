# %%
import os;
import json;
import builtins
import duckdb
import pandas as pd;
import matplotlib.pyplot as plt

def get_dataset_from_testcase(run):
    return run.split('_')[0]

dirs = [
    '/media/chesetti/sponge/join_hdd'
]
runs = []
for dir in dirs:
 for test_case in os.listdir(dir):
    if test_case == 'build':
        continue
    for run_name in os.listdir(os.path.join(dir, test_case, 'outputs', 'results')):
        if (run_name=="run"):
           continue
        json_file = builtins.open(os.path.join(dir, test_case, 'outputs', 'results',  run_name))
        run = (json.load(json_file))
        run['dataset'] = get_dataset_from_testcase(test_case)
        runs.append(run)
    for run_name in os.listdir(os.path.join(dir, test_case, 'outputs', 'results', 'run')):
        json_file = builtins.open(os.path.join(dir, test_case, 'outputs', 'results', 'run', run_name))
        run = (json.load(json_file))
        run['dataset'] = get_dataset_from_testcase(test_case)
        runs.append(run)
df = pd.json_normalize(runs)
print(df.columns)
display(df)
# Out:
# Index(['command', 'dataset', 'result.checksum', 'result.duration_ns',
#        'result.duration_sec', 'result.index_query_usec',
#        'result.inner_disk_cache_hit_count', 'result.inner_disk_fetch',
#        'result.inner_disk_fetch_size', 'result.inner_total_bytes_fetched',
#        'result.last_mile_fetch_usec', 'result.last_mile_search_usec',
#        'result.num_output_keys', 'result.outer_disk_fetch',
#        'result.outer_disk_fetch_size', 'result.outer_total_bytes_fetched',
#        'spec.algo', 'spec.algo_name', 'spec.check_checksum', 'spec.common_key',
#        'spec.inner_table', 'spec.key_size', 'spec.key_type',
#        'spec.load_sstable_in_mem', 'spec.name', 'spec.num_threads',
#        'spec.outer_table', 'spec.result_path', 'spec.value_size',
#        'spec.write_result_to_disk', 'iostat.bytes_read', 'iostat.bytes_wrtn',
#        'spec.index.epsilon', 'spec.index.search', 'spec.index.type',
#        'spec.index.leaf_size_in_pages'],
#       dtype='object')
#                                                command  dataset  \
# 0    /media/chesetti/sponge/join_hdd/build/benchmar...     wiki
# 1    /media/chesetti/sponge/join_hdd/build/benchmar...     wiki
# 2    /media/chesetti/sponge/join_hdd/build/benchmar...     wiki
# 3    /media/chesetti/sponge/join_hdd/build/benchmar...     wiki
# 4    /media/chesetti/sponge/join_hdd/build/benchmar...     wiki
# ..                                                 ...      ...
# 362  /media/chesetti/sponge/join_hdd/build/benchmar...  uniform
# 363  /media/chesetti/sponge/join_hdd/build/benchmar...  uniform
# 364  /media/chesetti/sponge/join_hdd/build/benchmar...  uniform
# 365  /media/chesetti/sponge/join_hdd/build/benchmar...  uniform
# 366  /media/chesetti/sponge/join_hdd/build/benchmar...  uniform
#
#      result.checksum  result.duration_ns  result.duration_sec  \
# 0                  0         25261707807            25.261708
# 1                  0         33297933576            33.297934
# 2                  0         45687938296            45.687938
# 3                  0         87624043626            87.624044
# 4                  0         38095773025            38.095773
# ..               ...                 ...                  ...
# 362                0        186259432553           186.259433
# 363                0         73718993974            73.718994
# 364                0        178200595145           178.200595
# 365                0         71134421586            71.134422
# 366                0         32421100275            32.421100
#
#      result.index_query_usec  result.inner_disk_cache_hit_count  \
# 0                          0                           90682527
# 1                    5210483                           17263692
# 2                          0                           92052819
# 3                          0                          180520752
# 4                          0                          141874594
# ..                       ...                                ...
# 362                        0                          799218748
# 363                        0                          199418645
# 364                        0                          799218748
# 365                        0                          256315096
# 366                  1195726                            1618652
#
#      result.inner_disk_fetch  result.inner_disk_fetch_size  \
# 0                     353270                          4096
# 1                     176635                          8192
# 2                     353270                          4096
# 3                     353270                          4096
# 4                     353270                          4096
# ..                       ...                           ...
# 362                   781251                          4096
# 363                   781251                          4096
# 364                   781251                          4096
# 365                   781250                          4096
# 366                   375229                          8192
#
#      result.inner_total_bytes_fetched  ...  \
# 0                          1446993920  ...
# 1                          1446993920  ...
# 2                          1446993920  ...
# 3                          1446993920  ...
# 4                          1446993920  ...
# ..                                ...  ...
# 362                        3200004096  ...
# 363                        3200004096  ...
# 364                        3200004096  ...
# 365                        3200000000  ...
# 366                        3073875968  ...
#
#                                       spec.outer_table  \
# 0    /media/chesetti/sponge/join_hdd/wiki_threads=1...
# 1    /media/chesetti/sponge/join_hdd/wiki_threads=1...
# 2    /media/chesetti/sponge/join_hdd/wiki_threads=1...
# 3    /media/chesetti/sponge/join_hdd/wiki_threads=1...
# 4    /media/chesetti/sponge/join_hdd/wiki_threads=1...
# ..                                                 ...
# 362  /media/chesetti/sponge/join_hdd/uniform_sparse...
# 363  /media/chesetti/sponge/join_hdd/uniform_sparse...
# 364  /media/chesetti/sponge/join_hdd/uniform_sparse...
# 365  /media/chesetti/sponge/join_hdd/uniform_sparse...
# 366  /media/chesetti/sponge/join_hdd/uniform_sparse...
#
#                                       spec.result_path  spec.value_size  \
# 0    /media/chesetti/sponge/join_hdd/wiki_threads=1...                8
# 1    /media/chesetti/sponge/join_hdd/wiki_threads=1...                8
# 2    /media/chesetti/sponge/join_hdd/wiki_threads=1...                8
# 3    /media/chesetti/sponge/join_hdd/wiki_threads=1...                8
# 4    /media/chesetti/sponge/join_hdd/wiki_threads=1...                8
# ..                                                 ...              ...
# 362  /media/chesetti/sponge/join_hdd/uniform_sparse...                8
# 363  /media/chesetti/sponge/join_hdd/uniform_sparse...                8
# 364  /media/chesetti/sponge/join_hdd/uniform_sparse...                8
# 365  /media/chesetti/sponge/join_hdd/uniform_sparse...                8
# 366  /media/chesetti/sponge/join_hdd/uniform_sparse...                8
#
#      spec.write_result_to_disk  iostat.bytes_read  iostat.bytes_wrtn  \
# 0                         True         1417236000            3388000
# 1                         True         1683720000          270136000
# 2                         True         1444832000           31184000
# 3                         True         2827324000         1413924000
# 4                         True         1683852000          270068000
# ..                         ...                ...                ...
# 362                       True         6250988000         3126356000
# 363                       True         3129120000            3664000
# 364                       True         6251136000         3126296000
# 365                       True         3423400000          298092000
# 366                       True         3045856000           31424000
#
#     spec.index.epsilon spec.index.search    spec.index.type  \
# 0                  NaN               NaN                NaN
# 1                256.0            binary  sampledflatpgm256
# 2                  NaN               NaN                NaN
# 3                  NaN               NaN                NaN
# 4                  NaN               NaN                NaN
# ..                 ...               ...                ...
# 362                NaN               NaN                NaN
# 363                NaN               NaN                NaN
# 364                NaN               NaN                NaN
# 365                NaN               NaN                NaN
# 366              256.0            binary              btree
#
#      spec.index.leaf_size_in_pages
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ..                             ...
# 362                            NaN
# 363                            NaN
# 364                            NaN
# 365                            NaN
# 366                            1.0
#
# [367 rows x 36 columns]

# %%
epsilon = {
    "pgm256": 256,
    "pgm1024": 1024,
    "pgm2048": 2048,
    "flatpgm256": 256,
    "flatpgm1024": 1024,
    "flatpgm2048": 2048,
    "flatpgm4096": 4096,
    "flatpgm8192": 8192,
    "hashjoin": 0,
    "btree": 0,
    "sj": 0,
    "sj2": 0,
    "standard_merge": 0
};
def indexType(x):
    if "pgm" in x:
        return "PGM"
    elif "btree" in x:
        return "BTREE"
    return "NA"

df["threads"] = df["spec.num_threads"]
df["duration_sec"] = df["result.duration_ns"] / (1000000000)
df["inner_disk_fetch"] = df["result.inner_disk_fetch"]
df['result_num_keys'] = df['result.num_output_keys']
df["ratio"] = df["spec.common_key"]
df["algo"] = df["spec.algo_name"]
df["epsilon"] = df["spec.index.epsilon"]
df["inner_bytes_fetched"] = df["result.inner_total_bytes_fetched"]
df["index_type"] = df["spec.algo_name"].map(lambda x: indexType(x))
df['disk_read_gb'] = df['iostat.bytes_read']/1e9
df['disk_wrtn_gb'] = df['iostat.bytes_wrtn']/1e9
#df['cdisk_read_gb'] = df['cgroup_iostat.bytes_read']/1e9
#df['cdisk_wrtn_gb'] = df['cgroup_iostat.bytes_wrtn']/1e9
df['checksum'] = df['result.checksum']
df['threads'] = df['spec.num_threads']

df['dataset'].unique()
df['result.num_output_keys'].unique()
duckdb.sql("SELECT * FROM df WHERE dataset='fb'")
# Out:
# ┌──────────────────────┬─────────┬─────────────────┬────────────────────┬───┬──────────────┬──────────────┬──────────┐
# │       command        │ dataset │ result.checksum │ result.duration_ns │ … │ disk_read_gb │ disk_wrtn_gb │ checksum │
# │       varchar        │ varchar │      int64      │       int64        │   │    double    │    double    │  int64   │
# ├──────────────────────┼─────────┼─────────────────┼────────────────────┼───┼──────────────┼──────────────┼──────────┤
# │ /media/chesetti/sp…  │ fb      │               0 │        69199161988 │ … │      3.13302 │     0.003616 │        0 │
# │ /media/chesetti/sp…  │ fb      │               0 │        45265317234 │ … │      3.42646 │     0.297908 │        0 │
# │ /media/chesetti/sp…  │ fb      │               0 │       105153923170 │ … │     3.160992 │     0.031708 │        0 │
# │ /media/chesetti/sp…  │ fb      │               0 │       209277072285 │ … │      6.25504 │     3.126504 │        0 │
# │ /media/chesetti/sp…  │ fb      │               0 │       105960532214 │ … │     3.160992 │     0.031708 │        0 │
# │ /media/chesetti/sp…  │ fb      │               0 │       443312744700 │ … │    53.838528 │     0.299696 │        0 │
# │ /media/chesetti/sp…  │ fb      │               0 │       248055134789 │ … │     6.262992 │     3.126696 │        0 │
# │ /media/chesetti/sp…  │ fb      │               0 │        80898631747 │ … │     3.427308 │     0.297944 │        0 │
# │ /media/chesetti/sp…  │ fb      │               0 │        19035153220 │ … │     1.419404 │     0.003244 │        0 │
# │ /media/chesetti/sp…  │ fb      │               0 │        56709543695 │ … │      3.43534 │     0.297984 │        0 │
# │          ·           │ ·       │               · │             ·      │ · │         ·    │         ·    │        · │
# │          ·           │ ·       │               · │             ·      │ · │         ·    │         ·    │        · │
# │          ·           │ ·       │               · │             ·      │ · │         ·    │         ·    │        · │
# │ /media/chesetti/sp…  │ fb      │               0 │       242047990093 │ … │     6.262916 │     3.126616 │        0 │
# │ /media/chesetti/sp…  │ fb      │               0 │        59087701255 │ … │     3.435336 │     0.297856 │        0 │
# │ /media/chesetti/sp…  │ fb      │               0 │        78126934000 │ … │     3.133016 │      0.00358 │        0 │
# │ /media/chesetti/sp…  │ fb      │               0 │        92371095079 │ … │     9.354756 │      0.03162 │        0 │
# │ /media/chesetti/sp…  │ fb      │               0 │       206185357764 │ … │     6.255028 │     3.126436 │        0 │
# │ /media/chesetti/sp…  │ fb      │               0 │        77507045809 │ … │     3.133028 │     0.003816 │        0 │
# │ /media/chesetti/sp…  │ fb      │               0 │      4024771818221 │ … │   504.391456 │     3.147548 │        0 │
# │ /media/chesetti/sp…  │ fb      │               0 │       204449319449 │ … │        6.255 │     3.126472 │        0 │
# │ /media/chesetti/sp…  │ fb      │               0 │        80066265516 │ … │     3.427344 │     0.298152 │        0 │
# │ /media/chesetti/sp…  │ fb      │               0 │        36033456697 │ … │     3.044612 │     0.031356 │        0 │
# ├──────────────────────┴─────────┴─────────────────┴────────────────────┴───┴──────────────┴──────────────┴──────────┤
# │ 72 rows (20 shown)                                                                            48 columns (7 shown) │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
def print_for_dataset(dataset, algos):
    print("## " + dataset)
    algo_filter = ''
    for algo in algos:
        algo_filter = algo_filter + f" OR algo='{algo}'"
    algo_filter = algo_filter[3:]
    rows = duckdb.sql(
        " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
        f" WHERE threads=1  AND dataset='{dataset}'"
        f" AND ({algo_filter})"
        " GROUP BY dataset, threads, ratio, algo"
        " ORDER BY ratio, threads"
    ).df()
    rows = rows.pivot(index='ratio', values='v', columns='algo')
    print(rows[algos].to_markdown())
    rows[algos].to_csv('/home/chesetti/Repos/LearnedJoinDiskExp/experiments/results/join_hdd/'+dataset+'.txt')



algos = ['lsj_sampledflatpgm256', 'inlj_btree256',  'sort_join', 'hash_join']
print_for_dataset("fb", algos)
#print_for_dataset("wiki", algos)
#print_for_dataset("osm", algos)
#print_for_dataset("books", algos)
# Out:
# ## fb
# |   ratio |   lsj_sampledflatpgm256 |   inlj_btree256 |   sort_join |   hash_join |
# |--------:|------------------------:|----------------:|------------:|------------:|
# |       1 |                194.082  |        237.848  |    204.449  |     209.646 |
# |      10 |                 45.2653 |         58.5688 |     80.8986 |     124.603 |
# |     100 |                 30.4713 |         37.0027 |     68.4672 |     105.961 |
# |    1000 |                 18.7375 |         19.053  |     66.3702 |      77.507 |

# %%
rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='256') AND dataset='fb'"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='256') AND dataset='fb'"
    " AND (algo='lsj_pgm256' OR algo='lsj_flatpgm256' OR algo='lsj_sampledpgm256' OR algo='lsj_sampledflatpgm256')"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='1024') AND dataset='wiki'"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='256') AND dataset='wiki'"
    " AND (algo='lsj_pgm256' OR algo='lsj_flatpgm256' OR algo='lsj_sampledpgm256' OR algo='lsj_sampledflatpgm256')"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='4096') AND dataset='books'"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='256') AND dataset='osm'"
    " AND (algo='lsj_pgm256' OR algo='lsj_flatpgm256' OR algo='lsj_sampledpgm256' OR algo='lsj_sampledflatpgm256')"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))
# Out:
# algo   hash_join  inlj_btree256  inlj_sampledflatpgm256  lsj_btree256  \
# ratio
# 1      80.931304      49.388665               44.882598     55.784585
# 10     55.292828       8.003186                8.061300      8.363397
# 100    45.841991       6.726388                6.664628      6.787620
# 1000   21.057477      22.401654               18.125491     22.804902
#
# algo   lsj_sampledflatpgm256  sort_join
# ratio
# 1                  32.612449  31.299311
# 10                  7.774270   8.724903
# 100                 6.632520   7.177175
# 1000               18.035658   7.082692
# algo   lsj_sampledflatpgm256
# ratio
# 1                  32.612449
# 10                  7.774270
# 100                 6.632520
# 1000               18.035658
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []

# %%
rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(inner_disk_fetch) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='256') AND dataset='wiki'"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(inner_disk_fetch) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='1024') AND dataset='wiki'"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(inner_disk_fetch) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='4096') AND dataset='wiki'"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []

# %%
def print_for_dataset(dataset, algos):
    print("## " + dataset)
    algo_filter = ''
    for algo in algos:
        algo_filter = algo_filter + f" OR algo='{algo}'"
    algo_filter = algo_filter[3:]
    rows = duckdb.sql(
        " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
        f" WHERE threads=1  AND dataset='{dataset}'"
        f" AND ({algo_filter})"
        " GROUP BY dataset, threads, ratio, algo"
        " ORDER BY ratio, threads"
    ).df()
    rows = rows.pivot(index='ratio', values='v', columns='algo')
    print(rows[algos].to_markdown())
    rows[algos].to_csv('all_indexes/'+dataset+'.csv')



algos = ['lsj_sampledflatpgm256', 'lsj_btree256',  'sort_join', 'hash_join']
print_for_dataset("fb", algos)
print_for_dataset("wiki", algos)
print_for_dataset("osm", algos)
print_for_dataset("books", algos)
# Out:
# ## fb
# ---------------------------------------------------------------------------
# BinderException                           Traceback (most recent call last)
# Cell In[8], line 21
#      16     rows[algos].to_csv('all_indexes/'+dataset+'.csv')
#      20 algos = ['lsj_sampledflatpgm256', 'lsj_btree256',  'sort_join', 'hash_join']
# ---> 21 print_for_dataset("fb", algos)
#      22 print_for_dataset("wiki", algos)
#      23 print_for_dataset("osm", algos)
#
# Cell In[8], line 7, in print_for_dataset(dataset, algos)
#       5     algo_filter = algo_filter + f" OR algo='{algo}'"
#       6 algo_filter = algo_filter[3:]
# ----> 7 rows = duckdb.sql(
#       8     " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
#       9     f" WHERE threads=1  AND dataset='{dataset}'"
#      10     f" AND ({algo_filter})"
#      11     " GROUP BY dataset, threads, ratio, algo"
#      12     " ORDER BY ratio, threads"
#      13 ).df()
#      14 rows = rows.pivot(index='ratio', values='v', columns='algo')
#      15 print(rows[algos].to_markdown())
#
# BinderException: Binder Error: Referenced column "threads" not found in FROM clause!
# Candidate bindings: "df.dataset"

# %%
algos = ['lsj_sampledflatpgm256', 'lsj_flatpgm256', 'lsj_radixspline256', 'lsj_rmi' , 'lsj_btree256', 'sort_join']
print_for_dataset("fb", algos)
print_for_dataset("wiki", algos)
print_for_dataset("osm", algos)
print_for_dataset("books", algos)
# Out:
# ## fb
# |   ratio |   lsj_sampledflatpgm256 |   lsj_flatpgm256 |   lsj_radixspline256 |   lsj_rmi |   lsj_btree256 |   sort_join |
# |--------:|------------------------:|-----------------:|---------------------:|----------:|---------------:|------------:|
# |       1 |               23.2294   |        22.4319   |            25.6702   | 20.3287   |       42.3009  |    11.7042  |
# |      10 |                3.68178  |         3.45073  |             4.30738  |  3.76312  |        5.83421 |     4.45029 |
# |     100 |                0.98362  |         1.01192  |             1.46279  |  1.25237  |        1.57196 |     3.12833 |
# |    1000 |                0.385151 |         0.353513 |             0.374326 |  0.275802 |        0.31908 |     2.86744 |
# ## wiki
# |   ratio |   lsj_sampledflatpgm256 |   lsj_flatpgm256 |   lsj_radixspline256 |   lsj_btree256 |   sort_join |
# |--------:|------------------------:|-----------------:|---------------------:|---------------:|------------:|
# |       1 |               10.1179   |         9.45712  |             9.97239  |      19.3136   |     5.38747 |
# |      10 |                3.07369  |         2.50171  |             3.14674  |       4.90736  |     2.74042 |
# |     100 |                0.698167 |         0.56145  |             0.854485 |       0.8996   |     1.33415 |
# |    1000 |                0.213931 |         0.208535 |             0.377251 |       0.322383 |     1.68557 |
# ## osm
# |   ratio |   lsj_sampledflatpgm256 |   lsj_flatpgm256 |   lsj_radixspline256 |   lsj_rmi |   lsj_btree256 |   sort_join |
# |--------:|------------------------:|-----------------:|---------------------:|----------:|---------------:|------------:|
# |       1 |               72.8033   |        73.47     |             83.6905  |  85.1446  |      175.609   |     45.4784 |
# |      10 |                7.99908  |         7.29272  |             13.9856  |  12.8359  |       22.2175  |     15.2134 |
# |     100 |                0.840453 |         1.265    |              4.30599 |   4.21186 |        4.68381 |     11.2403 |
# |    1000 |                0.146099 |         0.140748 |              1.23905 |   1.68892 |        1.11332 |     10.7955 |
# ## books
# |   ratio |   lsj_sampledflatpgm256 |   lsj_flatpgm256 |   lsj_radixspline256 |   lsj_rmi |   lsj_btree256 |   sort_join |
# |--------:|------------------------:|-----------------:|---------------------:|----------:|---------------:|------------:|
# |       1 |               72.8343   |        73.6028   |             83.7642  | 78.908    |      174.423   |     45.1136 |
# |      10 |                7.2696   |         6.94197  |             13.8679  | 12.7151   |       22.2364  |     15.456  |
# |     100 |                0.914571 |         1.16784  |              4.35452 |  3.6482   |        4.84053 |     11.1811 |
# |    1000 |                0.128371 |         0.131493 |              1.44302 |  0.936506 |        1.27291 |     10.9385 |

# %%
algos = ['lsj_radixspline256', 'lsj_radixspline1024', 'lsj_radixspline4096']
print_for_dataset("fb", algos)
print_for_dataset("wiki", algos)
print_for_dataset("osm", algos)
print_for_dataset("books", algos)
# Out:
# ## fb
# ---------------------------------------------------------------------------
# BinderException                           Traceback (most recent call last)
# Cell In[29], line 2
#       1 algos = ['lsj_radixspline256', 'lsj_radixspline1024', 'lsj_radixspline4096']
# ----> 2 print_for_dataset("fb", algos)
#       3 print_for_dataset("wiki", algos)
#       4 print_for_dataset("osm", algos)
#
# Cell In[27], line 7, in print_for_dataset(dataset, algos)
#       5     algo_filter = algo_filter + f" OR algo='{algo}'"
#       6 algo_filter = algo_filter[3:]
# ----> 7 rows = duckdb.sql(
#       8     " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
#       9     f" WHERE threads=1  AND dataset='{dataset}'"
#      10     f" AND ({algo_filter})"
#      11     " GROUP BY dataset, threads, ratio, algo"
#      12     " ORDER BY ratio, threads"
#      13 ).df()
#      14 rows = rows.pivot(index='ratio', values='v', columns='algo')
#      15 print(rows[algos].to_markdown())
#
# BinderException: Binder Error: Referenced column "threads" not found in FROM clause!
# Candidate bindings: "df.dataset"
