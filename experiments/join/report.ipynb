# %%
import os;
import json;
import builtins
import duckdb
import pandas as pd;
import matplotlib.pyplot as plt

def get_dataset_from_testcase(run):
    return run.split('_')[0]

dirs = [
    '/home/chesetti/sponge/join_sorted_threads1_ssd'
]
runs = []
for dir in dirs:
 for test_case in os.listdir(dir):
    if test_case == 'build':
        continue
    for run_name in os.listdir(os.path.join(dir, test_case, 'outputs', 'results')):
        if (run_name=="run"):
           continue
        json_file = builtins.open(os.path.join(dir, test_case, 'outputs', 'results',  run_name))
        run = (json.load(json_file))
        run['dataset'] = get_dataset_from_testcase(test_case)
        runs.append(run)
    for run_name in os.listdir(os.path.join(dir, test_case, 'outputs', 'results', 'run')):
        json_file = builtins.open(os.path.join(dir, test_case, 'outputs', 'results', 'run', run_name))
        run = (json.load(json_file))
        run['dataset'] = get_dataset_from_testcase(test_case)
        runs.append(run)
df = pd.json_normalize(runs)
print(df.columns)
display(df)
# Out:
# Index(['command', 'dataset', 'result.checksum', 'result.duration_ns',
#        'result.duration_sec', 'result.inner_disk_fetch',
#        'result.inner_disk_fetch_size', 'result.inner_total_bytes_fetched',
#        'result.num_output_keys', 'result.outer_disk_fetch',
#        'result.outer_disk_fetch_size', 'result.outer_total_bytes_fetched',
#        'spec.algo', 'spec.algo_name', 'spec.check_checksum', 'spec.common_key',
#        'spec.inner_table', 'spec.key_size', 'spec.key_type',
#        'spec.load_sstable_in_mem', 'spec.name', 'spec.num_threads',
#        'spec.outer_table', 'spec.result_path', 'spec.value_size',
#        'spec.write_result_to_disk', 'iostat.bytes_read', 'iostat.bytes_wrtn',
#        'spec.index.epsilon', 'spec.index.leaf_size_in_pages',
#        'spec.index.search', 'spec.index.type'],
#       dtype='object')
#                                               command dataset  \
# 0   /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 1   /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 2   /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 3   /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 4   /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 5   /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 6   /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 7   /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 8   /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 9   /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 10  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 11  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 12  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 13  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 14  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 15  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 16  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 17  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 18  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 19  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 20  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 21  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 22  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 23  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 24  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 25  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 26  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 27  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 28  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 29  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 30  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 31  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 32  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 33  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 34  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 35  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 36  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 37  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 38  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 39  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 40  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 41  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 42  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 43  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 44  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 45  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 46  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 47  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 48  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 49  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 50  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 51  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 52  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 53  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 54  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 55  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 56  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 57  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 58  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
# 59  /home/chesetti/sponge/join_sorted_threads1_ssd...      fb
#
#                      result.checksum  result.duration_ns  result.duration_sec  \
# 0   AEFEC92E33FEB8A2038E9CF0EB6076A1          6723823007             6.723823
# 1   197D7E88032185A864E14627A72FA7A5         32668075814            32.668076
# 2   197D7E88032185A864E14627A72FA7A5         46812754361            46.812754
# 3   FDF3C82C001773E4D6CD0C2D7C5232E8          6912586713             6.912587
# 4   197D7E88032185A864E14627A72FA7A5         38584626039            38.584626
# 5   F139F320CE1FB2C418CAEC8A653F6E75          7887181434             7.887181
# 6   FDF3C82C001773E4D6CD0C2D7C5232E8         18051440311            18.051440
# 7   AEFEC92E33FEB8A2038E9CF0EB6076A1          6599146280             6.599146
# 8   AEFEC92E33FEB8A2038E9CF0EB6076A1          6633091151             6.633091
# 9   197D7E88032185A864E14627A72FA7A5         43247820622            43.247821
# 10  F139F320CE1FB2C418CAEC8A653F6E75          7850967493             7.850967
# 11  F139F320CE1FB2C418CAEC8A653F6E75          8420548966             8.420549
# 12  197D7E88032185A864E14627A72FA7A5         53431452763            53.431453
# 13  FDF3C82C001773E4D6CD0C2D7C5232E8         17868305810            17.868306
# 14  197D7E88032185A864E14627A72FA7A5         45037252330            45.037252
# 15  197D7E88032185A864E14627A72FA7A5         28379363222            28.379363
# 16  FDF3C82C001773E4D6CD0C2D7C5232E8         23190056535            23.190057
# 17  FDF3C82C001773E4D6CD0C2D7C5232E8         23222172054            23.222172
# 18  FDF3C82C001773E4D6CD0C2D7C5232E8         22434947031            22.434947
# 19  F139F320CE1FB2C418CAEC8A653F6E75          7653252205             7.653252
# 20  FDF3C82C001773E4D6CD0C2D7C5232E8         22735018228            22.735018
# 21  197D7E88032185A864E14627A72FA7A5         48921781309            48.921781
# 22  197D7E88032185A864E14627A72FA7A5         54113861071            54.113861
# 23  F139F320CE1FB2C418CAEC8A653F6E75          8386433346             8.386433
# 24  AEFEC92E33FEB8A2038E9CF0EB6076A1          6494089159             6.494089
# 25  AEFEC92E33FEB8A2038E9CF0EB6076A1          6510349479             6.510349
# 26  F139F320CE1FB2C418CAEC8A653F6E75          7368487209             7.368487
# 27  AEFEC92E33FEB8A2038E9CF0EB6076A1          6635946458             6.635946
# 28  197D7E88032185A864E14627A72FA7A5         28303271271            28.303271
# 29  AEFEC92E33FEB8A2038E9CF0EB6076A1          6633846194             6.633846
# 30  FDF3C82C001773E4D6CD0C2D7C5232E8         23103074522            23.103075
# 31  FDF3C82C001773E4D6CD0C2D7C5232E8          6923658023             6.923658
# 32  F139F320CE1FB2C418CAEC8A653F6E75          7575141014             7.575141
# 33  F139F320CE1FB2C418CAEC8A653F6E75          8130280150             8.130280
# 34  197D7E88032185A864E14627A72FA7A5         27293491711            27.293492
# 35  AEFEC92E33FEB8A2038E9CF0EB6076A1          7244176781             7.244177
# 36  AEFEC92E33FEB8A2038E9CF0EB6076A1          6694616673             6.694617
# 37  FDF3C82C001773E4D6CD0C2D7C5232E8         22867518840            22.867519
# 38  197D7E88032185A864E14627A72FA7A5         48458660072            48.458660
# 39  AEFEC92E33FEB8A2038E9CF0EB6076A1          6929534171             6.929534
# 40  FDF3C82C001773E4D6CD0C2D7C5232E8         20864496627            20.864497
# 41  197D7E88032185A864E14627A72FA7A5         31732720362            31.732720
# 42  F139F320CE1FB2C418CAEC8A653F6E75          8441252789             8.441253
# 43  FDF3C82C001773E4D6CD0C2D7C5232E8         18313350181            18.313350
# 44  F139F320CE1FB2C418CAEC8A653F6E75          7702938863             7.702939
# 45  F139F320CE1FB2C418CAEC8A653F6E75          8080651113             8.080651
# 46  AEFEC92E33FEB8A2038E9CF0EB6076A1          6420174383             6.420174
# 47  197D7E88032185A864E14627A72FA7A5         29839147394            29.839147
# 48  AEFEC92E33FEB8A2038E9CF0EB6076A1          7079275887             7.079276
# 49  F139F320CE1FB2C418CAEC8A653F6E75          7696695754             7.696696
# 50  FDF3C82C001773E4D6CD0C2D7C5232E8         18065947959            18.065948
# 51  F139F320CE1FB2C418CAEC8A653F6E75          7791244799             7.791245
# 52  FDF3C82C001773E4D6CD0C2D7C5232E8         17823362518            17.823363
# 53  F139F320CE1FB2C418CAEC8A653F6E75          8059734205             8.059734
# 54  F139F320CE1FB2C418CAEC8A653F6E75          7437537141             7.437537
# 55  197D7E88032185A864E14627A72FA7A5         54693864322            54.693864
# 56  AEFEC92E33FEB8A2038E9CF0EB6076A1          6612406655             6.612407
# 57  AEFEC92E33FEB8A2038E9CF0EB6076A1          6645992148             6.645992
# 58  AEFEC92E33FEB8A2038E9CF0EB6076A1          6500644090             6.500644
# 59  FDF3C82C001773E4D6CD0C2D7C5232E8          6618694249             6.618694
#
#     result.inner_disk_fetch  result.inner_disk_fetch_size  \
# 0                    781250                          4096
# 1                    781250                          4096
# 2                    781250                          4096
# 3                    781247                          4096
# 4                   8578348                          8192
# 5                   2341735                          8192
# 6                    162224                          8192
# 7                    721072                          4096
# 8                    721072                          4096
# 9                   8578348                          8192
# 10                  2341735                          8192
# 11                   781250                          4096
# 12                   781250                          4096
# 13                   162224                          8192
# 14                  8578348                          8192
# 15                   390625                          8192
# 16                   176526                          4096
# 17                   176526                          4096
# 18                   176526                          4096
# 19                   781250                          4096
# 20                   176526                          4096
# 21                   781250                          4096
# 22                   781250                          4096
# 23                   781250                          4096
# 24                   386345                          8192
# 25                   915974                          8192
# 26                   390625                          8192
# 27                   915974                          8192
# 28                   781250                          4096
# 29                   721072                          4096
# 30                   176526                          4096
# 31                   781247                          4096
# 32                   781250                          4096
# 33                   781250                          4096
# 34                   390625                          8192
# 35                   915974                          8192
# 36                   721072                          4096
# 37                   176526                          4096
# 38                   781250                          4096
# 39                   781250                          4096
# 40                   168297                          8192
# 41                   390625                          8192
# 42                   781250                          4096
# 43                   168297                          8192
# 44                   781250                          4096
# 45                   781250                          4096
# 46                   386345                          8192
# 47                   781250                          4096
# 48                   781250                          4096
# 49                   390625                          8192
# 50                   168297                          8192
# 51                  2341735                          8192
# 52                   162224                          8192
# 53                   781250                          4096
# 54                   390625                          8192
# 55                   781250                          4096
# 56                   721072                          4096
# 57                   721072                          4096
# 58                   386345                          8192
# 59                   781247                          4096
#
#     result.inner_total_bytes_fetched  result.num_output_keys  \
# 0                         3199999984                 1990036
# 1                         3199999984               199999999
# 2                         3199999984               199999999
# 3                         3199987712                  199912
# 4                        70273820496               199999999
# 5                        19183482816                19033248
# 6                         1328939008                  199912
# 7                         2953510896                 1990036
# 8                         2953510896                 1990036
# 9                        70273820496               199999999
# 10                       19183482816                19033248
# 11                        3199999984                19033248
# 12                        3199999984               199999999
# 13                        1328939008                  199912
# 14                       70273820496               199999999
# 15                        3199999984               199999999
# 16                         723050496                  199912
# 17                         723050496                  199912
# 18                         723050496                  199912
# 19                        3199999984                19033248
# 20                         723050496                  199912
# 21                        3199999984               199999999
# 22                        3199999984               199999999
# 23                        3199999984                19033248
# 24                        3164936176                 1990036
# 25                        7503658992                 1990036
# 26                        3199999984                19033248
# 27                        7503658992                 1990036
# 28                        3199999984               199999999
# 29                        2953510896                 1990036
# 30                         723050496                  199912
# 31                        3199987712                  199912
# 32                        3199999984                19033248
# 33                        3199999984                19033248
# 34                        3199999984               199999999
# 35                        7503658992                 1990036
# 36                        2953510896                 1990036
# 37                         723050496                  199912
# 38                        3199999984               199999999
# 39                        3199999984                 1990036
# 40                        1378689024                  199912
# 41                        3199999984               199999999
# 42                        3199999984                19033248
# 43                        1378689024                  199912
# 44                        3199999984                19033248
# 45                        3199999984                19033248
# 46                        3164936176                 1990036
# 47                        3199999984               199999999
# 48                        3199999984                 1990036
# 49                        3199999984                19033248
# 50                        1378689024                  199912
# 51                       19183482816                19033248
# 52                        1328939008                  199912
# 53                        3199999984                19033248
# 54                        3199999984                19033248
# 55                        3199999984               199999999
# 56                        2953510896                 1990036
# 57                        2953510896                 1990036
# 58                        3164936176                 1990036
# 59                        3199987712                  199912
#
#     result.outer_disk_fetch  ...  \
# 0                      7774  ...
# 1                    781250  ...
# 2                    781250  ...
# 3                       781  ...
# 4                    781250  ...
# 5                     74349  ...
# 6                       781  ...
# 7                      7774  ...
# 8                      7774  ...
# 9                    781250  ...
# 10                    74349  ...
# 11                    74349  ...
# 12                   781250  ...
# 13                      781  ...
# 14                   781250  ...
# 15                   781250  ...
# 16                      781  ...
# 17                      781  ...
# 18                      781  ...
# 19                    74349  ...
# 20                      781  ...
# 21                   781250  ...
# 22                   781250  ...
# 23                    74349  ...
# 24                     7774  ...
# 25                     7774  ...
# 26                    74349  ...
# 27                     7774  ...
# 28                   781250  ...
# 29                     7774  ...
# 30                      781  ...
# 31                      781  ...
# 32                    74349  ...
# 33                    74349  ...
# 34                   781250  ...
# 35                     7774  ...
# 36                     7774  ...
# 37                      781  ...
# 38                   781250  ...
# 39                     7774  ...
# 40                      781  ...
# 41                   781250  ...
# 42                    74349  ...
# 43                      781  ...
# 44                    74349  ...
# 45                    74349  ...
# 46                     7774  ...
# 47                   781250  ...
# 48                     7774  ...
# 49                    74349  ...
# 50                      781  ...
# 51                    74349  ...
# 52                      781  ...
# 53                    74349  ...
# 54                    74349  ...
# 55                   781250  ...
# 56                     7774  ...
# 57                     7774  ...
# 58                     7774  ...
# 59                      781  ...
#
#                                      spec.outer_table  \
# 0   /home/chesetti/sponge/join_sorted_threads1_ssd...
# 1   /home/chesetti/sponge/join_sorted_threads1_ssd...
# 2   /home/chesetti/sponge/join_sorted_threads1_ssd...
# 3   /home/chesetti/sponge/join_sorted_threads1_ssd...
# 4   /home/chesetti/sponge/join_sorted_threads1_ssd...
# 5   /home/chesetti/sponge/join_sorted_threads1_ssd...
# 6   /home/chesetti/sponge/join_sorted_threads1_ssd...
# 7   /home/chesetti/sponge/join_sorted_threads1_ssd...
# 8   /home/chesetti/sponge/join_sorted_threads1_ssd...
# 9   /home/chesetti/sponge/join_sorted_threads1_ssd...
# 10  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 11  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 12  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 13  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 14  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 15  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 16  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 17  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 18  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 19  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 20  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 21  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 22  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 23  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 24  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 25  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 26  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 27  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 28  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 29  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 30  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 31  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 32  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 33  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 34  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 35  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 36  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 37  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 38  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 39  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 40  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 41  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 42  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 43  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 44  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 45  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 46  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 47  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 48  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 49  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 50  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 51  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 52  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 53  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 54  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 55  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 56  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 57  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 58  /home/chesetti/sponge/join_sorted_threads1_ssd...
# 59  /home/chesetti/sponge/join_sorted_threads1_ssd...
#
#                                      spec.result_path spec.value_size  \
# 0   /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 1   /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 2   /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 3   /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 4   /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 5   /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 6   /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 7   /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 8   /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 9   /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 10  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 11  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 12  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 13  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 14  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 15  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 16  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 17  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 18  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 19  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 20  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 21  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 22  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 23  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 24  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 25  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 26  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 27  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 28  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 29  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 30  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 31  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 32  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 33  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 34  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 35  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 36  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 37  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 38  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 39  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 40  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 41  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 42  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 43  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 44  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 45  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 46  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 47  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 48  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 49  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 50  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 51  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 52  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 53  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 54  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 55  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 56  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 57  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 58  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
# 59  /home/chesetti/sponge/join_sorted_threads1_ssd...               8
#
#    spec.write_result_to_disk  iostat.bytes_read  iostat.bytes_wrtn  \
# 0                       True                  0                  0
# 1                       True                  0                  0
# 2                       True                  0                  0
# 3                       True                  0                  0
# 4                       True                  0                  0
# 5                       True                  0                  0
# 6                       True                  0                  0
# 7                       True                  0                  0
# 8                       True                  0                  0
# 9                       True                  0                  0
# 10                      True                  0                  0
# 11                      True                  0                  0
# 12                      True                  0                  0
# 13                      True                  0                  0
# 14                      True                  0                  0
# 15                      True                  0                  0
# 16                      True                  0                  0
# 17                      True                  0                  0
# 18                      True                  0                  0
# 19                      True                  0                  0
# 20                      True                  0                  0
# 21                      True                  0                  0
# 22                      True                  0                  0
# 23                      True                  0                  0
# 24                      True                  0                  0
# 25                      True                  0                  0
# 26                      True                  0                  0
# 27                      True                  0                  0
# 28                      True                  0                  0
# 29                      True                  0                  0
# 30                      True                  0                  0
# 31                      True                  0                  0
# 32                      True                  0                  0
# 33                      True                  0                  0
# 34                      True                  0                  0
# 35                      True                  0                  0
# 36                      True                  0                  0
# 37                      True                  0                  0
# 38                      True                  0                  0
# 39                      True                  0                  0
# 40                      True                  0                  0
# 41                      True                  0                  0
# 42                      True                  0                  0
# 43                      True                  0                  0
# 44                      True                  0                  0
# 45                      True                  0                  0
# 46                      True                  0                  0
# 47                      True                  0                  0
# 48                      True                  0                  0
# 49                      True                  0                  0
# 50                      True                  0                  0
# 51                      True                  0                  0
# 52                      True                  0                  0
# 53                      True                  0                  0
# 54                      True                  0                  0
# 55                      True                  0                  0
# 56                      True                  0                  0
# 57                      True                  0                  0
# 58                      True                  0                  0
# 59                      True                  0                  0
#
#    spec.index.epsilon  spec.index.leaf_size_in_pages spec.index.search  \
# 0                 NaN                            NaN               NaN
# 1                 NaN                            NaN               NaN
# 2               256.0                            1.0            binary
# 3                 NaN                            NaN               NaN
# 4               256.0                            NaN            binary
# 5               256.0                            NaN            binary
# 6               256.0                            NaN            binary
# 7               256.0                            1.0            binary
# 8               256.0                            1.0            binary
# 9               256.0                            NaN            binary
# 10              256.0                            NaN            binary
# 11                NaN                            NaN               NaN
# 12              256.0                            1.0            binary
# 13              256.0                            NaN            binary
# 14              256.0                            NaN            binary
# 15              256.0                            NaN            binary
# 16              256.0                            1.0            binary
# 17              256.0                            1.0            binary
# 18              256.0                            1.0            binary
# 19              256.0                            1.0            binary
# 20              256.0                            1.0            binary
# 21              256.0                            1.0            binary
# 22              256.0                            1.0            binary
# 23                NaN                            NaN               NaN
# 24              256.0                            NaN            binary
# 25              256.0                            NaN            binary
# 26              256.0                            NaN            binary
# 27              256.0                            NaN            binary
# 28                NaN                            NaN               NaN
# 29              256.0                            1.0            binary
# 30              256.0                            1.0            binary
# 31                NaN                            NaN               NaN
# 32              256.0                            1.0            binary
# 33              256.0                            1.0            binary
# 34              256.0                            NaN            binary
# 35              256.0                            NaN            binary
# 36              256.0                            1.0            binary
# 37              256.0                            1.0            binary
# 38              256.0                            1.0            binary
# 39                NaN                            NaN               NaN
# 40              256.0                            NaN            binary
# 41              256.0                            NaN            binary
# 42                NaN                            NaN               NaN
# 43              256.0                            NaN            binary
# 44              256.0                            1.0            binary
# 45              256.0                            1.0            binary
# 46              256.0                            NaN            binary
# 47                NaN                            NaN               NaN
# 48                NaN                            NaN               NaN
# 49              256.0                            NaN            binary
# 50              256.0                            NaN            binary
# 51              256.0                            NaN            binary
# 52              256.0                            NaN            binary
# 53              256.0                            1.0            binary
# 54              256.0                            NaN            binary
# 55              256.0                            1.0            binary
# 56              256.0                            1.0            binary
# 57              256.0                            1.0            binary
# 58              256.0                            NaN            binary
# 59                NaN                            NaN               NaN
#
#       spec.index.type
# 0                 NaN
# 1                 NaN
# 2               btree
# 3                 NaN
# 4   sampledflatpgm256
# 5   sampledflatpgm256
# 6   sampledflatpgm256
# 7               btree
# 8               btree
# 9   sampledflatpgm256
# 10  sampledflatpgm256
# 11                NaN
# 12              btree
# 13  sampledflatpgm256
# 14  sampledflatpgm256
# 15  sampledflatpgm256
# 16              btree
# 17              btree
# 18              btree
# 19              btree
# 20              btree
# 21              btree
# 22              btree
# 23                NaN
# 24  sampledflatpgm256
# 25  sampledflatpgm256
# 26  sampledflatpgm256
# 27  sampledflatpgm256
# 28                NaN
# 29              btree
# 30              btree
# 31                NaN
# 32              btree
# 33              btree
# 34  sampledflatpgm256
# 35  sampledflatpgm256
# 36              btree
# 37              btree
# 38              btree
# 39                NaN
# 40  sampledflatpgm256
# 41  sampledflatpgm256
# 42                NaN
# 43  sampledflatpgm256
# 44              btree
# 45              btree
# 46  sampledflatpgm256
# 47                NaN
# 48                NaN
# 49  sampledflatpgm256
# 50  sampledflatpgm256
# 51  sampledflatpgm256
# 52  sampledflatpgm256
# 53              btree
# 54  sampledflatpgm256
# 55              btree
# 56              btree
# 57              btree
# 58  sampledflatpgm256
# 59                NaN
#
# [60 rows x 32 columns]

# %%
epsilon = {
    "pgm256": 256,
    "pgm1024": 1024,
    "pgm2048": 2048,
    "flatpgm256": 256,
    "flatpgm1024": 1024,
    "flatpgm2048": 2048,
    "flatpgm4096": 4096,
    "flatpgm8192": 8192,
    "hashjoin": 0,
    "btree": 0,
    "sj": 0,
    "sj2": 0,
    "standard_merge": 0
};
def indexType(x):
    if "pgm" in x:
        return "PGM"
    elif "btree" in x:
        return "BTREE"
    return "NA"

df["threads"] = df["spec.num_threads"]
df["duration_sec"] = df["result.duration_ns"] / (1000000000)
df["inner_disk_fetch"] = df["result.inner_disk_fetch"]
df['result_num_keys'] = df['result.num_output_keys']
df["ratio"] = df["spec.common_key"]
df["algo"] = df["spec.algo_name"]
df["epsilon"] = df["spec.index.epsilon"]
df["inner_bytes_fetched"] = df["result.inner_total_bytes_fetched"]
df["index_type"] = df["spec.algo_name"].map(lambda x: indexType(x))
df['disk_read_gb'] = df['iostat.bytes_read']/1e9
df['disk_wrtn_gb'] = df['iostat.bytes_wrtn']/1e9
#df['cdisk_read_gb'] = df['cgroup_iostat.bytes_read']/1e9
#df['cdisk_wrtn_gb'] = df['cgroup_iostat.bytes_wrtn']/1e9

df['dataset'].unique()
df['result.num_output_keys'].unique()
duckdb.sql("SELECT * FROM df WHERE dataset='fb'")
# Out:
# ┌──────────────────────┬─────────┬──────────────────────┬───┬────────────┬──────────────┬──────────────┐
# │       command        │ dataset │   result.checksum    │ … │ index_type │ disk_read_gb │ disk_wrtn_gb │
# │       varchar        │ varchar │       varchar        │   │  varchar   │    double    │    double    │
# ├──────────────────────┼─────────┼──────────────────────┼───┼────────────┼──────────────┼──────────────┤
# │ /home/chesetti/spo…  │ fb      │ AEFEC92E33FEB8A203…  │ … │ NA         │          0.0 │          0.0 │
# │ /home/chesetti/spo…  │ fb      │ 197D7E88032185A864…  │ … │ NA         │          0.0 │          0.0 │
# │ /home/chesetti/spo…  │ fb      │ 197D7E88032185A864…  │ … │ BTREE      │          0.0 │          0.0 │
# │ /home/chesetti/spo…  │ fb      │ FDF3C82C001773E4D6…  │ … │ NA         │          0.0 │          0.0 │
# │ /home/chesetti/spo…  │ fb      │ 197D7E88032185A864…  │ … │ PGM        │          0.0 │          0.0 │
# │ /home/chesetti/spo…  │ fb      │ F139F320CE1FB2C418…  │ … │ PGM        │          0.0 │          0.0 │
# │ /home/chesetti/spo…  │ fb      │ FDF3C82C001773E4D6…  │ … │ PGM        │          0.0 │          0.0 │
# │ /home/chesetti/spo…  │ fb      │ AEFEC92E33FEB8A203…  │ … │ BTREE      │          0.0 │          0.0 │
# │ /home/chesetti/spo…  │ fb      │ AEFEC92E33FEB8A203…  │ … │ BTREE      │          0.0 │          0.0 │
# │ /home/chesetti/spo…  │ fb      │ 197D7E88032185A864…  │ … │ PGM        │          0.0 │          0.0 │
# │          ·           │ ·       │          ·           │ · │  ·         │           ·  │           ·  │
# │          ·           │ ·       │          ·           │ · │  ·         │           ·  │           ·  │
# │          ·           │ ·       │          ·           │ · │  ·         │           ·  │           ·  │
# │ /home/chesetti/spo…  │ fb      │ FDF3C82C001773E4D6…  │ … │ PGM        │          0.0 │          0.0 │
# │ /home/chesetti/spo…  │ fb      │ F139F320CE1FB2C418…  │ … │ PGM        │          0.0 │          0.0 │
# │ /home/chesetti/spo…  │ fb      │ FDF3C82C001773E4D6…  │ … │ PGM        │          0.0 │          0.0 │
# │ /home/chesetti/spo…  │ fb      │ F139F320CE1FB2C418…  │ … │ BTREE      │          0.0 │          0.0 │
# │ /home/chesetti/spo…  │ fb      │ F139F320CE1FB2C418…  │ … │ PGM        │          0.0 │          0.0 │
# │ /home/chesetti/spo…  │ fb      │ 197D7E88032185A864…  │ … │ BTREE      │          0.0 │          0.0 │
# │ /home/chesetti/spo…  │ fb      │ AEFEC92E33FEB8A203…  │ … │ BTREE      │          0.0 │          0.0 │
# │ /home/chesetti/spo…  │ fb      │ AEFEC92E33FEB8A203…  │ … │ BTREE      │          0.0 │          0.0 │
# │ /home/chesetti/spo…  │ fb      │ AEFEC92E33FEB8A203…  │ … │ PGM        │          0.0 │          0.0 │
# │ /home/chesetti/spo…  │ fb      │ FDF3C82C001773E4D6…  │ … │ NA         │          0.0 │          0.0 │
# ├──────────────────────┴─────────┴──────────────────────┴───┴────────────┴──────────────┴──────────────┤
# │ 60 rows (20 shown)                                                              43 columns (6 shown) │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
print(duckdb.sql("SELECT RATIO,ALGO,INDEX_TYPE,DISK_READ_GB,DISK_WRTN_GB,DURATION_SEC FROM df WHERE dataset='fb' ORDER BY RATIO,ALGO").df().to_markdown())
# Out:
# |    |   ratio | algo                   | index_type   |   disk_read_gb |   disk_wrtn_gb |   duration_sec |
# |---:|--------:|:-----------------------|:-------------|---------------:|---------------:|---------------:|
# |  0 |       1 | inlj_btree256          | BTREE        |              0 |              0 |       53.4315  |
# |  1 |       1 | inlj_btree256          | BTREE        |              0 |              0 |       54.1139  |
# |  2 |       1 | inlj_btree256          | BTREE        |              0 |              0 |       54.6939  |
# |  3 |       1 | inlj_sampledflatpgm256 | PGM          |              0 |              0 |       38.5846  |
# |  4 |       1 | inlj_sampledflatpgm256 | PGM          |              0 |              0 |       45.0373  |
# |  5 |       1 | inlj_sampledflatpgm256 | PGM          |              0 |              0 |       43.2478  |
# |  6 |       1 | lsj_btree256           | BTREE        |              0 |              0 |       46.8128  |
# |  7 |       1 | lsj_btree256           | BTREE        |              0 |              0 |       48.9218  |
# |  8 |       1 | lsj_btree256           | BTREE        |              0 |              0 |       48.4587  |
# |  9 |       1 | lsj_sampledflatpgm256  | PGM          |              0 |              0 |       28.3794  |
# | 10 |       1 | lsj_sampledflatpgm256  | PGM          |              0 |              0 |       31.7327  |
# | 11 |       1 | lsj_sampledflatpgm256  | PGM          |              0 |              0 |       27.2935  |
# | 12 |       1 | sort_join              | NA           |              0 |              0 |       28.3033  |
# | 13 |       1 | sort_join              | NA           |              0 |              0 |       29.8391  |
# | 14 |       1 | sort_join              | NA           |              0 |              0 |       32.6681  |
# | 15 |      10 | inlj_btree256          | BTREE        |              0 |              0 |        8.08065 |
# | 16 |      10 | inlj_btree256          | BTREE        |              0 |              0 |        8.13028 |
# | 17 |      10 | inlj_btree256          | BTREE        |              0 |              0 |        8.05973 |
# | 18 |      10 | inlj_sampledflatpgm256 | PGM          |              0 |              0 |        7.85097 |
# | 19 |      10 | inlj_sampledflatpgm256 | PGM          |              0 |              0 |        7.79124 |
# | 20 |      10 | inlj_sampledflatpgm256 | PGM          |              0 |              0 |        7.88718 |
# | 21 |      10 | lsj_btree256           | BTREE        |              0 |              0 |        7.70294 |
# | 22 |      10 | lsj_btree256           | BTREE        |              0 |              0 |        7.65325 |
# | 23 |      10 | lsj_btree256           | BTREE        |              0 |              0 |        7.57514 |
# | 24 |      10 | lsj_sampledflatpgm256  | PGM          |              0 |              0 |        7.6967  |
# | 25 |      10 | lsj_sampledflatpgm256  | PGM          |              0 |              0 |        7.36849 |
# | 26 |      10 | lsj_sampledflatpgm256  | PGM          |              0 |              0 |        7.43754 |
# | 27 |      10 | sort_join              | NA           |              0 |              0 |        8.38643 |
# | 28 |      10 | sort_join              | NA           |              0 |              0 |        8.42055 |
# | 29 |      10 | sort_join              | NA           |              0 |              0 |        8.44125 |
# | 30 |     100 | inlj_btree256          | BTREE        |              0 |              0 |        6.63385 |
# | 31 |     100 | inlj_btree256          | BTREE        |              0 |              0 |        6.64599 |
# | 32 |     100 | inlj_btree256          | BTREE        |              0 |              0 |        6.69462 |
# | 33 |     100 | inlj_sampledflatpgm256 | PGM          |              0 |              0 |        6.51035 |
# | 34 |     100 | inlj_sampledflatpgm256 | PGM          |              0 |              0 |        6.63595 |
# | 35 |     100 | inlj_sampledflatpgm256 | PGM          |              0 |              0 |        7.24418 |
# | 36 |     100 | lsj_btree256           | BTREE        |              0 |              0 |        6.61241 |
# | 37 |     100 | lsj_btree256           | BTREE        |              0 |              0 |        6.63309 |
# | 38 |     100 | lsj_btree256           | BTREE        |              0 |              0 |        6.59915 |
# | 39 |     100 | lsj_sampledflatpgm256  | PGM          |              0 |              0 |        6.49409 |
# | 40 |     100 | lsj_sampledflatpgm256  | PGM          |              0 |              0 |        6.42017 |
# | 41 |     100 | lsj_sampledflatpgm256  | PGM          |              0 |              0 |        6.50064 |
# | 42 |     100 | sort_join              | NA           |              0 |              0 |        6.72382 |
# | 43 |     100 | sort_join              | NA           |              0 |              0 |        6.92953 |
# | 44 |     100 | sort_join              | NA           |              0 |              0 |        7.07928 |
# | 45 |    1000 | inlj_btree256          | BTREE        |              0 |              0 |       23.1031  |
# | 46 |    1000 | inlj_btree256          | BTREE        |              0 |              0 |       22.8675  |
# | 47 |    1000 | inlj_btree256          | BTREE        |              0 |              0 |       23.2222  |
# | 48 |    1000 | inlj_sampledflatpgm256 | PGM          |              0 |              0 |       18.3134  |
# | 49 |    1000 | inlj_sampledflatpgm256 | PGM          |              0 |              0 |       20.8645  |
# | 50 |    1000 | inlj_sampledflatpgm256 | PGM          |              0 |              0 |       18.0659  |
# | 51 |    1000 | lsj_btree256           | BTREE        |              0 |              0 |       22.735   |
# | 52 |    1000 | lsj_btree256           | BTREE        |              0 |              0 |       22.4349  |
# | 53 |    1000 | lsj_btree256           | BTREE        |              0 |              0 |       23.1901  |
# | 54 |    1000 | lsj_sampledflatpgm256  | PGM          |              0 |              0 |       18.0514  |
# | 55 |    1000 | lsj_sampledflatpgm256  | PGM          |              0 |              0 |       17.8234  |
# | 56 |    1000 | lsj_sampledflatpgm256  | PGM          |              0 |              0 |       17.8683  |
# | 57 |    1000 | sort_join              | NA           |              0 |              0 |        6.92366 |
# | 58 |    1000 | sort_join              | NA           |              0 |              0 |        6.91259 |
# | 59 |    1000 | sort_join              | NA           |              0 |              0 |        6.61869 |

# %%
rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='256') AND dataset='fb'"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='256') AND dataset='fb'"
    " AND (algo='lsj_pgm256' OR algo='lsj_flatpgm256' OR algo='lsj_sampledpgm256' OR algo='lsj_sampledflatpgm256')"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='1024') AND dataset='wiki'"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='256') AND dataset='wiki'"
    " AND (algo='lsj_pgm256' OR algo='lsj_flatpgm256' OR algo='lsj_sampledpgm256' OR algo='lsj_sampledflatpgm256')"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='4096') AND dataset='books'"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='256') AND dataset='osm'"
    " AND (algo='lsj_pgm256' OR algo='lsj_flatpgm256' OR algo='lsj_sampledpgm256' OR algo='lsj_sampledflatpgm256')"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))
# Out:
# algo   lsj_btree256  lsj_flatpgm256  lsj_pgm256  lsj_radixspline256  \
# ratio
# 1         42.300910       22.431856   27.055335           25.670175
# 10         5.834207        3.450734    4.009025            4.307376
# 100        1.571960        0.940489    1.313947            1.462793
# 1000       0.319080        0.243864    0.343778            0.374326
#
# algo   lsj_sampledflatpgm256  sort_join
# ratio
# 1                  23.229437  11.704229
# 10                  3.152880   3.904735
# 100                 0.983620   2.998804
# 1000                0.385151   2.560174
# algo   lsj_flatpgm256  lsj_pgm256  lsj_sampledflatpgm256
# ratio
# 1           22.431856   27.055335              23.229437
# 10           3.450734    4.009025               3.152880
# 100          0.940489    1.313947               0.983620
# 1000         0.243864    0.343778               0.385151
# algo   lsj_radixspline1024  sort_join
# ratio
# 1                10.778464   5.129859
# 10                3.267205   2.262956
# 100               0.926267   1.313295
# 1000              0.414278   1.190710
# algo   lsj_flatpgm256  lsj_pgm256  lsj_sampledflatpgm256
# ratio
# 1            9.457123   11.353547              10.117874
# 10           2.501715    3.032850               3.073691
# 100          0.561450    0.750796               0.698167
# 1000         0.208535    0.317465               0.213931
# algo   lsj_radixspline4096  sort_join
# ratio
# 1               103.147400  47.431663
# 10               15.031332  15.704701
# 100               3.462918  11.254792
# 1000              2.263213  11.304608
# algo   lsj_flatpgm256  lsj_pgm256  lsj_sampledflatpgm256
# ratio
# 1           82.983117  117.044278              88.978646
# 10          12.694236   16.350766              13.171777
# 100          3.748309    3.820507               3.968178
# 1000         1.110650    1.380077               1.210211

# %%
rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(inner_disk_fetch) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='256') AND dataset='wiki'"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(inner_disk_fetch) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='1024') AND dataset='wiki'"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(inner_disk_fetch) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='4096') AND dataset='wiki'"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))
# Out:
# algo   lsj_btree256  lsj_flatpgm256  lsj_pgm256  lsj_radixspline256  \
# ratio
# 1          353270.0        176635.0    176635.0            353270.0
# 10         353270.0        176611.0    176610.0            353209.0
# 100        348811.0        172933.0    172958.0            345715.0
# 1000       149418.0        102884.0    102878.0            194161.0
#
# algo   lsj_sampledflatpgm256  sort_join
# ratio
# 1                   176635.0   353270.0
# 10                  176635.0   353270.0
# 100                 176405.0   353270.0
# 1000                118522.0   353270.0
# algo   lsj_radixspline1024  sort_join
# ratio
# 1                  88318.0   353270.0
# 10                 88316.0   353270.0
# 100                88099.0   353270.0
# 1000               79616.0   353270.0
# algo   lsj_radixspline4096  sort_join
# ratio
# 1                  22080.0   353270.0
# 10                 22080.0   353270.0
# 100                22079.0   353270.0
# 1000               21960.0   353270.0

# %%
def print_for_dataset(dataset, algos):
    print("## " + dataset)
    algo_filter = ''
    for algo in algos:
        algo_filter = algo_filter + f" OR algo='{algo}'"
    algo_filter = algo_filter[3:]
    rows = duckdb.sql(
        " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
        f" WHERE threads=1  AND dataset='{dataset}'"
        f" AND ({algo_filter})"
        " GROUP BY dataset, threads, ratio, algo"
        " ORDER BY ratio, threads"
    ).df()
    rows = rows.pivot(index='ratio', values='v', columns='algo')
    print(rows[algos].to_markdown())
    rows[algos].to_csv('all_indexes/'+dataset+'.csv')



algos = ['lsj_sampledflatpgm256', 'lsj_btree256',  'sort_join']
#print_for_dataset("fb", algos)
#print_for_dataset("wiki", algos)
print_for_dataset("osm", algos)
print_for_dataset("books", algos)
# Out:
# ## osm
# |   ratio |   lsj_sampledflatpgm256 |   lsj_btree256 |   sort_join |
# |--------:|------------------------:|---------------:|------------:|
# |       1 |                88.9786  |      175.609   |     47.7724 |
# |      10 |                13.1718  |       22.2175  |     15.3804 |
# |     100 |                 3.96818 |        4.68381 |     11.4066 |
# |    1000 |                 1.21021 |        1.11332 |     10.7698 |
# ## books
# |   ratio |   lsj_sampledflatpgm256 |   lsj_btree256 |   sort_join |
# |--------:|------------------------:|---------------:|------------:|
# |       1 |                87.8691  |      174.423   |     47.4317 |
# |      10 |                13.3788  |       22.2364  |     15.7047 |
# |     100 |                 3.54946 |        4.84053 |     11.2548 |
# |    1000 |                 1.20184 |        1.27291 |     11.3046 |

# %%
algos = ['lsj_sampledflatpgm256', 'lsj_flatpgm256', 'lsj_radixspline256', 'lsj_rmi' , 'lsj_btree256', 'sort_join']
print_for_dataset("fb", algos)
print_for_dataset("wiki", algos)
print_for_dataset("osm", algos)
print_for_dataset("books", algos)
# Out:
# ## fb
# |   ratio |   lsj_sampledflatpgm256 |   lsj_flatpgm256 |   lsj_radixspline256 |   lsj_rmi |   lsj_btree256 |   sort_join |
# |--------:|------------------------:|-----------------:|---------------------:|----------:|---------------:|------------:|
# |       1 |               23.2294   |        22.4319   |            25.6702   | 20.3287   |       42.3009  |    11.7042  |
# |      10 |                3.68178  |         3.45073  |             4.30738  |  3.76312  |        5.83421 |     4.45029 |
# |     100 |                0.98362  |         1.01192  |             1.46279  |  1.25237  |        1.57196 |     3.12833 |
# |    1000 |                0.385151 |         0.353513 |             0.374326 |  0.275802 |        0.31908 |     2.86744 |
# ## wiki
# |   ratio |   lsj_sampledflatpgm256 |   lsj_flatpgm256 |   lsj_radixspline256 |   lsj_btree256 |   sort_join |
# |--------:|------------------------:|-----------------:|---------------------:|---------------:|------------:|
# |       1 |               10.1179   |         9.45712  |             9.97239  |      19.3136   |     5.38747 |
# |      10 |                3.07369  |         2.50171  |             3.14674  |       4.90736  |     2.74042 |
# |     100 |                0.698167 |         0.56145  |             0.854485 |       0.8996   |     1.33415 |
# |    1000 |                0.213931 |         0.208535 |             0.377251 |       0.322383 |     1.68557 |
# ## osm
# |   ratio |   lsj_sampledflatpgm256 |   lsj_flatpgm256 |   lsj_radixspline256 |   lsj_rmi |   lsj_btree256 |   sort_join |
# |--------:|------------------------:|-----------------:|---------------------:|----------:|---------------:|------------:|
# |       1 |               72.8033   |        73.47     |             83.6905  |  85.1446  |      175.609   |     45.4784 |
# |      10 |                7.99908  |         7.29272  |             13.9856  |  12.8359  |       22.2175  |     15.2134 |
# |     100 |                0.840453 |         1.265    |              4.30599 |   4.21186 |        4.68381 |     11.2403 |
# |    1000 |                0.146099 |         0.140748 |              1.23905 |   1.68892 |        1.11332 |     10.7955 |
# ## books
# |   ratio |   lsj_sampledflatpgm256 |   lsj_flatpgm256 |   lsj_radixspline256 |   lsj_rmi |   lsj_btree256 |   sort_join |
# |--------:|------------------------:|-----------------:|---------------------:|----------:|---------------:|------------:|
# |       1 |               72.8343   |        73.6028   |             83.7642  | 78.908    |      174.423   |     45.1136 |
# |      10 |                7.2696   |         6.94197  |             13.8679  | 12.7151   |       22.2364  |     15.456  |
# |     100 |                0.914571 |         1.16784  |              4.35452 |  3.6482   |        4.84053 |     11.1811 |
# |    1000 |                0.128371 |         0.131493 |              1.44302 |  0.936506 |        1.27291 |     10.9385 |

# %%
algos = ['lsj_radixspline256', 'lsj_radixspline1024', 'lsj_radixspline4096']
print_for_dataset("fb", algos)
print_for_dataset("wiki", algos)
print_for_dataset("osm", algos)
print_for_dataset("books", algos)
# Out:
# ## fb
# ---------------------------------------------------------------------------
# BinderException                           Traceback (most recent call last)
# Cell In[29], line 2
#       1 algos = ['lsj_radixspline256', 'lsj_radixspline1024', 'lsj_radixspline4096']
# ----> 2 print_for_dataset("fb", algos)
#       3 print_for_dataset("wiki", algos)
#       4 print_for_dataset("osm", algos)
#
# Cell In[27], line 7, in print_for_dataset(dataset, algos)
#       5     algo_filter = algo_filter + f" OR algo='{algo}'"
#       6 algo_filter = algo_filter[3:]
# ----> 7 rows = duckdb.sql(
#       8     " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
#       9     f" WHERE threads=1  AND dataset='{dataset}'"
#      10     f" AND ({algo_filter})"
#      11     " GROUP BY dataset, threads, ratio, algo"
#      12     " ORDER BY ratio, threads"
#      13 ).df()
#      14 rows = rows.pivot(index='ratio', values='v', columns='algo')
#      15 print(rows[algos].to_markdown())
#
# BinderException: Binder Error: Referenced column "threads" not found in FROM clause!
# Candidate bindings: "df.dataset"
