# %%
import os;
import json;
import builtins
import duckdb
import pandas as pd;
import matplotlib.pyplot as plt

def get_dataset_from_testcase(run):
    return run.split('_')[0]

dirs = [
    '/media/datahdd/chesetti/sponge/join_sorted_threads1_hdd'
]
runs = []
for dir in dirs:
 for test_case in os.listdir(dir):
    if test_case == 'build':
        continue
    for run_name in os.listdir(os.path.join(dir, test_case, 'outputs', 'results')):
        if (run_name=="run"):
           continue
        json_file = builtins.open(os.path.join(dir, test_case, 'outputs', 'results',  run_name))
        run = (json.load(json_file))
        run['dataset'] = get_dataset_from_testcase(test_case)
        runs.append(run)
    for run_name in os.listdir(os.path.join(dir, test_case, 'outputs', 'results', 'run')):
        json_file = builtins.open(os.path.join(dir, test_case, 'outputs', 'results', 'run', run_name))
        run = (json.load(json_file))
        run['dataset'] = get_dataset_from_testcase(test_case)
        runs.append(run)
df = pd.json_normalize(runs)
print(df.columns)
display(df)
# Out:
# Index(['command', 'dataset', 'result.checksum', 'result.duration_ns',
#        'result.duration_sec', 'result.inner_disk_fetch',
#        'result.inner_disk_fetch_size', 'result.inner_total_bytes_fetched',
#        'result.num_output_keys', 'result.outer_disk_fetch',
#        'result.outer_disk_fetch_size', 'result.outer_total_bytes_fetched',
#        'spec.algo', 'spec.algo_name', 'spec.check_checksum', 'spec.common_key',
#        'spec.inner_table', 'spec.key_size', 'spec.key_type',
#        'spec.load_sstable_in_mem', 'spec.name', 'spec.num_threads',
#        'spec.outer_table', 'spec.result_path', 'spec.value_size',
#        'spec.write_result_to_disk', 'iostat.bytes_read', 'iostat.bytes_wrtn',
#        'spec.index.epsilon', 'spec.index.search', 'spec.index.type',
#        'spec.index.leaf_size_in_pages'],
#       dtype='object')
#                                               command dataset  \
# 0   /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 1   /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 2   /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 3   /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 4   /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 5   /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 6   /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 7   /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 8   /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 9   /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 10  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 11  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 12  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 13  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 14  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 15  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 16  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 17  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 18  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 19  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 20  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 21  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 22  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 23  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 24  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 25  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 26  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 27  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 28  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 29  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 30  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 31  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 32  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 33  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 34  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 35  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 36  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 37  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 38  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 39  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 40  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 41  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 42  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 43  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 44  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 45  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 46  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 47  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 48  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 49  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 50  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 51  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 52  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 53  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 54  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 55  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 56  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 57  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 58  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
# 59  /media/datahdd/chesetti/sponge/join_sorted_thr...      fb
#
#                      result.checksum  result.duration_ns  result.duration_sec  \
# 0   DA4E7FC81BE9B89EA2DB39EA6A6EE847         17234807921            17.234808
# 1   B52377108C2CEAC64B4E42227CF164E2         24566332985            24.566333
# 2   B52377108C2CEAC64B4E42227CF164E2         22674935785            22.674936
# 3   197D7E88032185A864E14627A72FA7A5         55372984564            55.372985
# 4   B52377108C2CEAC64B4E42227CF164E2         22292692265            22.292692
# 5   DA4E7FC81BE9B89EA2DB39EA6A6EE847         16440484707            16.440485
# 6   B52377108C2CEAC64B4E42227CF164E2         23125051708            23.125052
# 7   B52377108C2CEAC64B4E42227CF164E2         22850057970            22.850058
# 8   197D7E88032185A864E14627A72FA7A5         71386599354            71.386599
# 9   197D7E88032185A864E14627A72FA7A5         70344299825            70.344300
# 10  DA4E7FC81BE9B89EA2DB39EA6A6EE847         17226632916            17.226633
# 11  DA4E7FC81BE9B89EA2DB39EA6A6EE847         17235952504            17.235953
# 12  3506BF2DEF94C9E104C06C2E685AC562         17951297214            17.951297
# 13  DA4E7FC81BE9B89EA2DB39EA6A6EE847         17343158931            17.343159
# 14  197D7E88032185A864E14627A72FA7A5         46589907521            46.589908
# 15  197D7E88032185A864E14627A72FA7A5         81177283001            81.177283
# 16  197D7E88032185A864E14627A72FA7A5         46754040211            46.754040
# 17  197D7E88032185A864E14627A72FA7A5         52358554593            52.358555
# 18  DA4E7FC81BE9B89EA2DB39EA6A6EE847         
#
#     result.outer_disk_fetch  ...  \
# 0                       781  ...
# 1                     74348  ...
# 2                     74348  ...
# 3                    781250  ...
# 4                     74348  ...
# 5                       781  ...
# 6                     74348  ...
# 7                     74348  ...
# 8                    781250  ...
# 9                    781250  ...
# 10                      781  ...
# 11                      781  ...
# 12                     7774  ...
# 13                      781  ...
# 14                   781250  ...
# 15                   781250  ...
# 16                   781250  ...
# 17                   781250  ...
# 18                      781  ...
# 19                    74348  ...
# 20                   781250  ...
# 21                    74348  ...
# 22                     7774  ...
# 23                     7774  ...
# 24                     7774  ...
# 25                      781  ...
# 26                     7774  ...
# 27                      781  ...
# 28                   781250  ...
# 29                      781  ...
# 30                    74348  ...
# 31                    74348  ...
# 32                      781  ...
# 33                    74348  ...
# 34                    74348  ...
# 35                     7774  ...
# 36                     7774  ...
# 37                      781  ...
# 38                    74348  ...
# 39                    74348  ...
# 40                     7774  ...
# 41                      781  ...
# 42                     7774  ...
# 43                     7774  ...
# 44                   781250  ...
# 45                      781  ...
# 46                     7774  ...
# 47                      781  ...
# 48                     7774  ...
# 49                     7774  ...
# 50                   781250  ...
# 51                      781  ...
# 52                   781250  ...
# 53                    74348  ...
# 54                     7774  ...
# 55                   781250  ...
# 56                   781250  ...
# 57                   781250  ...
# 58                    74348  ...
# 59                     7774  ...
#
#                                      spec.outer_table  \
# 0   /media/datahdd/chesetti/sponge/join_sorted_thr...
# 1   /media/datahdd/chesetti/sponge/join_sorted_thr...
# 2   /media/datahdd/chesetti/sponge/join_sorted_thr...
# 3   /media/datahdd/chesetti/sponge/join_sorted_thr...
# 4   /media/datahdd/chesetti/sponge/join_sorted_thr...
# 5   /media/datahdd/chesetti/sponge/join_sorted_thr...
# 6   /media/datahdd/chesetti/sponge/join_sorted_thr...
# 7   /media/datahdd/chesetti/sponge/join_sorted_thr...
# 8   /media/datahdd/chesetti/sponge/join_sorted_thr...
# 9   /media/datahdd/chesetti/sponge/join_sorted_thr...
# 10  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 11  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 12  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 13  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 14  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 15  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 16  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 17  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 18  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 19  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 20  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 21  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 22  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 23  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 24  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 25  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 26  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 27  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 28  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 29  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 30  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 31  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 32  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 33  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 34  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 35  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 36  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 37  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 38  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 39  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 40  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 41  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 42  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 43  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 44  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 45  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 46  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 47  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 48  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 49  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 50  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 51  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 52  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 53  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 54  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 55  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 56  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 57  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 58  /media/datahdd/chesetti/sponge/join_sorted_thr...
# 59  /media/datahdd/chesetti/sponge/join_sorted_thr...
#
#                                      spec.result_path spec.value_size  \
# 0   /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 1   /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 2   /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 3   /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 4   /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 5   /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 6   /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 7   /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 8   /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 9   /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 10  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 11  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 12  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 13  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 14  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 15  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 16  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 17  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 18  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 19  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 20  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 21  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 22  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 23  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 24  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 25  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 26  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 27  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 28  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 29  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 30  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 31  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 32  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 33  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 34  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 35  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 36  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 37  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 38  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 39  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 40  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 41  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 42  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 43  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 44  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 45  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 46  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 47  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 48  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 49  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 50  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 51  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 52  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 53  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 54  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 55  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 56  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 57  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 58  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
# 59  /media/datahdd/chesetti/sponge/join_sorted_thr...               8
#
#    spec.write_result_to_disk  iostat.bytes_read  iostat.bytes_wrtn  \
# 0                       True         3132844000            3272000
# 1                       True         3426248000          204152000
# 2                       True         3426156000              80000
# 3                       True         6262756000         2631124000
# 4                       True         3427160000             184000
# 5                       True         2895436000           31188000
# 6                       True         3435016000              92000
# 7                       True         3435104000             124000
# 8                       True         6253836000         2660512000
# 9                       True         6254756000         2654700000
# 10                      True         2898412000            1148000
# 11                      True         2592944000              92000
# 12                      True         3159864000              88000
# 13                      True         2592892000            1588000
# 14                      True         6262724000         1866704000
# 15                      True         6253780000         3068028000
# 16                      True         6253900000         1665300000
# 17                      True         6253760000         2892912000
# 18                      True         2592940000             148000
# 19                      True         3426196000             104000
# 20                      True         6262716000         2817512000
# 21                      True         3435144000          227580000
# 22                      True         3168844000             116000
# 23                      True         3160760000           15740000
# 24                      True         3159952000              76000
# 25                      True         2900928000              92000
# 26                      True         3168792000             304000
# 27                      True         2592932000              72000
# 28                      True         6262740000         1965636000
# 29                      True         2593088000              68000
# 30                      True         3426312000             100000
# 31                      True         3435112000          255652000
# 32                      True         2592928000             104000
# 33                      True         3435120000              92000
# 34                      True         3426248000              88000
# 35                      True         3168800000            3260000
# 36                      True         3159932000              64000
# 37                      True         2900984000             184000
# 38                      True         3427124000              88000
# 39                      True         3426240000             132000
# 40                      True         3160016000             128000
# 41                      True         2898528000             288000
# 42                      True         3168844000             296000
# 43                      True         3160804000             132000
# 44                      True         6262864000         2303508000
# 45                      True         2900932000             104000
# 46                      True         3168856000             168000
# 47                      True         3132876000             172000
# 48                      True         3159920000           12708000
# 49                      True         3160848000             176000
# 50                      True         6253836000         3125612000
# 51                      True         3132876000              72000
# 52                      True         6262880000         1893516000
# 53                      True         3435144000             172000
# 54                      True         3159912000             116000
# 55                      True         6254740000         2606780000
# 56                      True         6253872000         2463288000
# 57                      True         6254756000         2904304000
# 58                      True         3427196000              92000
# 59                      True         3168832000             116000
#
#    spec.index.epsilon  spec.index.search    spec.index.type  \
# 0                 NaN                NaN                NaN
# 1               256.0             binary  sampledflatpgm256
# 2               256.0             binary  sampledflatpgm256
# 3               256.0             binary              btree
# 4                 NaN                NaN                NaN
# 5               256.0             binary  sampledflatpgm256
# 6               256.0             binary              btree
# 7               256.0             binary              btree
# 8               256.0             binary  sampledflatpgm256
# 9                 NaN                NaN                NaN
# 10              256.0             binary  sampledflatpgm256
# 11              256.0             binary              btree
# 12              256.0             binary  sampledflatpgm256
# 13              256.0             binary              btree
# 14              256.0             binary              btree
# 15              256.0             binary  sampledflatpgm256
# 16              256.0             binary  sampledflatpgm256
# 17              256.0             binary  sampledflatpgm256
# 18              256.0             binary              btree
# 19              256.0             binary  sampledflatpgm256
# 20              256.0             binary              btree
# 21              256.0             binary              btree
# 22              256.0             binary              btree
# 23                NaN                NaN                NaN
# 24              256.0             binary  sampledflatpgm256
# 25              256.0             binary  sampledflatpgm256
# 26              256.0             binary              btree
# 27              256.0             binary              btree
# 28              256.0             binary              btree
# 29              256.0             binary              btree
# 30              256.0             binary  sampledflatpgm256
# 31              256.0             binary              btree
# 32              256.0             binary              btree
# 33              256.0             binary              btree
# 34              256.0             binary  sampledflatpgm256
# 35              256.0             binary              btree
# 36              256.0             binary  sampledflatpgm256
# 37              256.0             binary  sampledflatpgm256
# 38                NaN                NaN                NaN
# 39              256.0             binary  sampledflatpgm256
# 40              256.0             binary  sampledflatpgm256
# 41              256.0             binary  sampledflatpgm256
# 42              256.0             binary              btree
# 43                NaN                NaN                NaN
# 44              256.0             binary              btree
# 45              256.0             binary  sampledflatpgm256
# 46              256.0             binary              btree
# 47                NaN                NaN                NaN
# 48              256.0             binary  sampledflatpgm256
# 49                NaN                NaN                NaN
# 50              256.0             binary  sampledflatpgm256
# 51                NaN                NaN                NaN
# 52              256.0             binary              btree
# 53              256.0             binary              btree
# 54              256.0             binary  sampledflatpgm256
# 55                NaN                NaN                NaN
# 56              256.0             binary  sampledflatpgm256
# 57                NaN                NaN                NaN
# 58                NaN                NaN                NaN
# 59              256.0             binary              btree
#
#     spec.index.leaf_size_in_pages
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             1.0
# 4                             NaN
# 5                             NaN
# 6                             1.0
# 7                             1.0
# 8                             NaN
# 9                             NaN
# 10                            NaN
# 11                            1.0
# 12                            NaN
# 13                            1.0
# 14                            1.0
# 15                            NaN
# 16                            NaN
# 17                            NaN
# 18                            1.0
# 19                            NaN
# 20                            1.0
# 21                            1.0
# 22                            1.0
# 23                            NaN
# 24                            NaN
# 25                            NaN
# 26                            1.0
# 27                            1.0
# 28                            1.0
# 29                            1.0
# 30                            NaN
# 31                            1.0
# 32                            1.0
# 33                            1.0
# 34                            NaN
# 35                            1.0
# 36                            NaN
# 37                            NaN
# 38                            NaN
# 39                            NaN
# 40                            NaN
# 41                            NaN
# 42                            1.0
# 43                            NaN
# 44                            1.0
# 45                            NaN
# 46                            1.0
# 47                            NaN
# 48                            NaN
# 49                            NaN
# 50                            NaN
# 51                            NaN
# 52                            1.0
# 53                            1.0
# 54                            NaN
# 55                            NaN
# 56                            NaN
# 57                            NaN
# 58                            NaN
# 59                            1.0
#
# [60 rows x 32 columns]

# %%
epsilon = {
    "pgm256": 256,
    "pgm1024": 1024,
    "pgm2048": 2048,
    "flatpgm256": 256,
    "flatpgm1024": 1024,
    "flatpgm2048": 2048,
    "flatpgm4096": 4096,
    "flatpgm8192": 8192,
    "hashjoin": 0,
    "btree": 0,
    "sj": 0,
    "sj2": 0,
    "standard_merge": 0
};
def indexType(x):
    if "pgm" in x:
        return "PGM"
    elif "btree" in x:
        return "BTREE"
    return "NA"

df["threads"] = df["spec.num_threads"]
df["duration_sec"] = df["result.duration_ns"] / (1000000000)
df["inner_disk_fetch"] = df["result.inner_disk_fetch"]
df['result_num_keys'] = df['result.num_output_keys']
df["ratio"] = df["spec.common_key"]
df["algo"] = df["spec.algo_name"]
df["epsilon"] = df["spec.index.epsilon"]
df["inner_bytes_fetched"] = df["result.inner_total_bytes_fetched"]
df["index_type"] = df["spec.algo_name"].map(lambda x: indexType(x))
df['disk_read_gb'] = df['iostat.bytes_read']/1e9
df['disk_wrtn_gb'] = df['iostat.bytes_wrtn']/1e9
#df['cdisk_read_gb'] = df['cgroup_iostat.bytes_read']/1e9
#df['cdisk_wrtn_gb'] = df['cgroup_iostat.bytes_wrtn']/1e9
df['checksum'] = df['result.checksum']

df['dataset'].unique()
df['result.num_output_keys'].unique()
duckdb.sql("SELECT * FROM df WHERE dataset='fb'")
# Out:
# ┌──────────────────────┬─────────┬──────────────────────┬───┬──────────────┬──────────────┬──────────────────────┐
# │       command        │ dataset │   result.checksum    │ … │ disk_read_gb │ disk_wrtn_gb │       checksum       │
# │       varchar        │ varchar │       varchar        │   │    double    │    double    │       varchar        │
# ├──────────────────────┼─────────┼──────────────────────┼───┼──────────────┼──────────────┼──────────────────────┤
# │ /media/datahdd/che…  │ fb      │ DA4E7FC81BE9B89EA2…  │ … │     3.132844 │     0.003272 │ DA4E7FC81BE9B89EA2…  │
# │ /media/datahdd/che…  │ fb      │ B52377108C2CEAC64B…  │ … │     3.426248 │     0.204152 │ B52377108C2CEAC64B…  │
# │ /media/datahdd/che…  │ fb      │ B52377108C2CEAC64B…  │ … │     3.426156 │        8e-05 │ B52377108C2CEAC64B…  │
# │ /media/datahdd/che…  │ fb      │ 197D7E88032185A864…  │ … │     6.262756 │     2.631124 │ 197D7E88032185A864…  │
# │ /media/datahdd/che…  │ fb      │ B52377108C2CEAC64B…  │ … │      3.42716 │     0.000184 │ B52377108C2CEAC64B…  │
# │ /media/datahdd/che…  │ fb      │ DA4E7FC81BE9B89EA2…  │ … │     2.895436 │     0.031188 │ DA4E7FC81BE9B89EA2…  │
# │ /media/datahdd/che…  │ fb      │ B52377108C2CEAC64B…  │ … │     3.435016 │      9.2e-05 │ B52377108C2CEAC64B…  │
# │ /media/datahdd/che…  │ fb      │ B52377108C2CEAC64B…  │ … │     3.435104 │     0.000124 │ B52377108C2CEAC64B…  │
# │ /media/datahdd/che…  │ fb      │ 197D7E88032185A864…  │ … │     6.253836 │     2.660512 │ 197D7E88032185A864…  │
# │ /media/datahdd/che…  │ fb      │ 197D7E88032185A864…  │ … │     6.254756 │       2.6547 │ 197D7E88032185A864…  │
# │          ·           │ ·       │          ·           │ · │         ·    │          ·   │          ·           │
# │          ·           │ ·       │          ·           │ · │         ·    │          ·   │          ·           │
# │          ·           │ ·       │          ·           │ · │         ·    │          ·   │          ·           │
# │ /media/datahdd/che…  │ fb      │ 197D7E88032185A864…  │ … │     6.253836 │     3.125612 │ 197D7E88032185A864…  │
# │ /media/datahdd/che…  │ fb      │ DA4E7FC81BE9B89EA2…  │ … │     3.132876 │      7.2e-05 │ DA4E7FC81BE9B89EA2…  │
# │ /media/datahdd/che…  │ fb      │ 197D7E88032185A864…  │ … │      6.26288 │     1.893516 │ 197D7E88032185A864…  │
# │ /media/datahdd/che…  │ fb      │ B52377108C2CEAC64B…  │ … │     3.435144 │     0.000172 │ B52377108C2CEAC64B…  │
# │ /media/datahdd/che…  │ fb      │ 3506BF2DEF94C9E104…  │ … │     3.159912 │     0.000116 │ 3506BF2DEF94C9E104…  │
# │ /media/datahdd/che…  │ fb      │ 197D7E88032185A864…  │ … │      6.25474 │      2.60678 │ 197D7E88032185A864…  │
# │ /media/datahdd/che…  │ fb      │ 197D7E88032185A864…  │ … │     6.253872 │     2.463288 │ 197D7E88032185A864…  │
# │ /media/datahdd/che…  │ fb      │ 197D7E88032185A864…  │ … │     6.254756 │     2.904304 │ 197D7E88032185A864…  │
# │ /media/datahdd/che…  │ fb      │ B52377108C2CEAC64B…  │ … │     3.427196 │      9.2e-05 │ B52377108C2CEAC64B…  │
# │ /media/datahdd/che…  │ fb      │ 3506BF2DEF94C9E104…  │ … │     3.168832 │     0.000116 │ 3506BF2DEF94C9E104…  │
# ├──────────────────────┴─────────┴──────────────────────┴───┴──────────────┴──────────────┴──────────────────────┤
# │ 60 rows (20 shown)                                                                        44 columns (6 shown) │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
print(duckdb.sql("SELECT RATIO,ALGO,CHECKSUM FROM df WHERE dataset='fb' ORDER BY ratio,algo").df().to_markdown())
# Out:
# |    |   ratio | algo                   | checksum                         |
# |---:|--------:|:-----------------------|:---------------------------------|
# |  0 |       1 | inlj_btree256          | 197D7E88032185A864E14627A72FA7A5 |
# |  1 |       1 | inlj_btree256          | 197D7E88032185A864E14627A72FA7A5 |
# |  2 |       1 | inlj_btree256          | 197D7E88032185A864E14627A72FA7A5 |
# |  3 |       1 | inlj_sampledflatpgm256 | 197D7E88032185A864E14627A72FA7A5 |
# |  4 |       1 | inlj_sampledflatpgm256 | 197D7E88032185A864E14627A72FA7A5 |
# |  5 |       1 | inlj_sampledflatpgm256 | 197D7E88032185A864E14627A72FA7A5 |
# |  6 |       1 | lsj_btree256           | 197D7E88032185A864E14627A72FA7A5 |
# |  7 |       1 | lsj_btree256           | 197D7E88032185A864E14627A72FA7A5 |
# |  8 |       1 | lsj_btree256           | 197D7E88032185A864E14627A72FA7A5 |
# |  9 |       1 | lsj_sampledflatpgm256  | 197D7E88032185A864E14627A72FA7A5 |
# | 10 |       1 | lsj_sampledflatpgm256  | 197D7E88032185A864E14627A72FA7A5 |
"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='256') AND dataset='fb'"
    " AND (algo='lsj_pgm256' OR algo='lsj_flatpgm256' OR algo='lsj_sampledpgm256' OR algo='lsj_sampledflatpgm256')"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='1024') AND dataset='wiki'"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='256') AND dataset='wiki'"
    " AND (algo='lsj_pgm256' OR algo='lsj_flatpgm256' OR algo='lsj_sampledpgm256' OR algo='lsj_sampledflatpgm256')"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='4096') AND dataset='books'"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='256') AND dataset='osm'"
    " AND (algo='lsj_pgm256' OR algo='lsj_flatpgm256' OR algo='lsj_sampledpgm256' OR algo='lsj_sampledflatpgm256')"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))
# Out:
# algo   lsj_btree256  lsj_flatpgm256  lsj_pgm256  lsj_radixspline256  \
# ratio
# 1         42.300910       22.431856   27.055335           25.670175
# 10         5.834207        3.450734    4.009025            4.307376
# 100        1.571960        0.940489    1.313947            1.462793
# 1000       0.319080        0.243864    0.343778            0.374326
#
# algo   lsj_sampledflatpgm256  sort_join
# ratio
# 1                  23.229437  11.704229
# 10                  3.152880   3.904735
# 100                 0.983620   2.998804
# 1000                0.385151   2.560174
# algo   lsj_flatpgm256  lsj_pgm256  lsj_sampledflatpgm256
# ratio
# 1           22.431856   27.055335              23.229437
# 10           3.450734    4.009025               3.152880
# 100          0.940489    1.313947               0.983620
# 1000         0.243864    0.343778               0.385151
# algo   lsj_radixspline1024  sort_join
# ratio
# 1                10.778464   5.129859
# 10                3.267205   2.262956
# 100               0.926267   1.313295
# 1000              0.414278   1.190710
# algo   lsj_flatpgm256  lsj_pgm256  lsj_sampledflatpgm256
# ratio
# 1            9.457123   11.353547              10.117874
# 10           2.501715    3.032850               3.073691
# 100          0.561450    0.750796               0.698167
# 1000         0.208535    0.317465               0.213931
# algo   lsj_radixspline4096  sort_join
# ratio
# 1               103.147400  47.431663
# 10               15.031332  15.704701
# 100               3.462918  11.254792
# 1000              2.263213  11.304608
# algo   lsj_flatpgm256  lsj_pgm256  lsj_sampledflatpgm256
# ratio
# 1           82.983117  117.044278              88.978646
# 10          12.694236   16.350766              13.171777
# 100          3.748309    3.820507               3.968178
# 1000         1.110650    1.380077               1.210211

# %%
rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(inner_disk_fetch) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='256') AND dataset='wiki'"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(inner_disk_fetch) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='1024') AND dataset='wiki'"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))

rows = duckdb.sql(
    " SELECT ratio, algo, MEDIAN(inner_disk_fetch) as v FROM df"
    f" WHERE threads=1 AND (algo='hash_join' OR algo='sort_join' or epsilon='4096') AND dataset='wiki'"
    " GROUP BY dataset, threads, ratio, algo"
    " ORDER BY ratio, threads"
).df()
display(rows.pivot(index='ratio', values='v', columns='algo'))
# Out:
# algo   lsj_btree256  lsj_flatpgm256  lsj_pgm256  lsj_radixspline256  \
# ratio
# 1          353270.0        176635.0    176635.0            353270.0
# 10         353270.0        176611.0    176610.0            353209.0
# 100        348811.0        172933.0    172958.0            345715.0
# 1000       149418.0        102884.0    102878.0            194161.0
#
# algo   lsj_sampledflatpgm256  sort_join
# ratio
# 1                   176635.0   353270.0
# 10                  176635.0   353270.0
# 100                 176405.0   353270.0
# 1000                118522.0   353270.0
# algo   lsj_radixspline1024  sort_join
# ratio
# 1                  88318.0   353270.0
# 10                 88316.0   353270.0
# 100                88099.0   353270.0
# 1000               79616.0   353270.0
# algo   lsj_radixspline4096  sort_join
# ratio
# 1                  22080.0   353270.0
# 10                 22080.0   353270.0
# 100                22079.0   353270.0
# 1000               21960.0   353270.0

# %%
def print_for_dataset(dataset, algos):
    print("## " + dataset)
    algo_filter = ''
    for algo in algos:
        algo_filter = algo_filter + f" OR algo='{algo}'"
    algo_filter = algo_filter[3:]
    rows = duckdb.sql(
        " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
        f" WHERE threads=1  AND dataset='{dataset}'"
        f" AND ({algo_filter})"
        " GROUP BY dataset, threads, ratio, algo"
        " ORDER BY ratio, threads"
    ).df()
    rows = rows.pivot(index='ratio', values='v', columns='algo')
    print(rows[algos].to_markdown())
    rows[algos].to_csv('all_indexes/'+dataset+'.csv')



algos = ['lsj_sampledflatpgm256', 'lsj_btree256',  'sort_join']
#print_for_dataset("fb", algos)
#print_for_dataset("wiki", algos)
print_for_dataset("osm", algos)
print_for_dataset("books", algos)
# Out:
# ## osm
# |   ratio |   lsj_sampledflatpgm256 |   lsj_btree256 |   sort_join |
# |--------:|------------------------:|---------------:|------------:|
# |       1 |                88.9786  |      175.609   |     47.7724 |
# |      10 |                13.1718  |       22.2175  |     15.3804 |
# |     100 |                 3.96818 |        4.68381 |     11.4066 |
# |    1000 |                 1.21021 |        1.11332 |     10.7698 |
# ## books
# |   ratio |   lsj_sampledflatpgm256 |   lsj_btree256 |   sort_join |
# |--------:|------------------------:|---------------:|------------:|
# |       1 |                87.8691  |      174.423   |     47.4317 |
# |      10 |                13.3788  |       22.2364  |     15.7047 |
# |     100 |                 3.54946 |        4.84053 |     11.2548 |
# |    1000 |                 1.20184 |        1.27291 |     11.3046 |

# %%
algos = ['lsj_sampledflatpgm256', 'lsj_flatpgm256', 'lsj_radixspline256', 'lsj_rmi' , 'lsj_btree256', 'sort_join']
print_for_dataset("fb", algos)
print_for_dataset("wiki", algos)
print_for_dataset("osm", algos)
print_for_dataset("books", algos)
# Out:
# ## fb
# |   ratio |   lsj_sampledflatpgm256 |   lsj_flatpgm256 |   lsj_radixspline256 |   lsj_rmi |   lsj_btree256 |   sort_join |
# |--------:|------------------------:|-----------------:|---------------------:|----------:|---------------:|------------:|
# |       1 |               23.2294   |        22.4319   |            25.6702   | 20.3287   |       42.3009  |    11.7042  |
# |      10 |                3.68178  |         3.45073  |             4.30738  |  3.76312  |        5.83421 |     4.45029 |
# |     100 |                0.98362  |         1.01192  |             1.46279  |  1.25237  |        1.57196 |     3.12833 |
# |    1000 |                0.385151 |         0.353513 |             0.374326 |  0.275802 |        0.31908 |     2.86744 |
# ## wiki
# |   ratio |   lsj_sampledflatpgm256 |   lsj_flatpgm256 |   lsj_radixspline256 |   lsj_btree256 |   sort_join |
# |--------:|------------------------:|-----------------:|---------------------:|---------------:|------------:|
# |       1 |               10.1179   |         9.45712  |             9.97239  |      19.3136   |     5.38747 |
# |      10 |                3.07369  |         2.50171  |             3.14674  |       4.90736  |     2.74042 |
# |     100 |                0.698167 |         0.56145  |             0.854485 |       0.8996   |     1.33415 |
# |    1000 |                0.213931 |         0.208535 |             0.377251 |       0.322383 |     1.68557 |
# ## osm
# |   ratio |   lsj_sampledflatpgm256 |   lsj_flatpgm256 |   lsj_radixspline256 |   lsj_rmi |   lsj_btree256 |   sort_join |
# |--------:|------------------------:|-----------------:|---------------------:|----------:|---------------:|------------:|
# |       1 |               72.8033   |        73.47     |             83.6905  |  85.1446  |      175.609   |     45.4784 |
# |      10 |                7.99908  |         7.29272  |             13.9856  |  12.8359  |       22.2175  |     15.2134 |
# |     100 |                0.840453 |         1.265    |              4.30599 |   4.21186 |        4.68381 |     11.2403 |
# |    1000 |                0.146099 |         0.140748 |              1.23905 |   1.68892 |        1.11332 |     10.7955 |
# ## books
# |   ratio |   lsj_sampledflatpgm256 |   lsj_flatpgm256 |   lsj_radixspline256 |   lsj_rmi |   lsj_btree256 |   sort_join |
# |--------:|------------------------:|-----------------:|---------------------:|----------:|---------------:|------------:|
# |       1 |               72.8343   |        73.6028   |             83.7642  | 78.908    |      174.423   |     45.1136 |
# |      10 |                7.2696   |         6.94197  |             13.8679  | 12.7151   |       22.2364  |     15.456  |
# |     100 |                0.914571 |         1.16784  |              4.35452 |  3.6482   |        4.84053 |     11.1811 |
# |    1000 |                0.128371 |         0.131493 |              1.44302 |  0.936506 |        1.27291 |     10.9385 |

# %%
algos = ['lsj_radixspline256', 'lsj_radixspline1024', 'lsj_radixspline4096']
print_for_dataset("fb", algos)
print_for_dataset("wiki", algos)
print_for_dataset("osm", algos)
print_for_dataset("books", algos)
# Out:
# ## fb
# ---------------------------------------------------------------------------
# BinderException                           Traceback (most recent call last)
# Cell In[29], line 2
#       1 algos = ['lsj_radixspline256', 'lsj_radixspline1024', 'lsj_radixspline4096']
# ----> 2 print_for_dataset("fb", algos)
#       3 print_for_dataset("wiki", algos)
#       4 print_for_dataset("osm", algos)
#
# Cell In[27], line 7, in print_for_dataset(dataset, algos)
#       5     algo_filter = algo_filter + f" OR algo='{algo}'"
#       6 algo_filter = algo_filter[3:]
# ----> 7 rows = duckdb.sql(
#       8     " SELECT ratio, algo, MEDIAN(duration_sec) as v FROM df"
#       9     f" WHERE threads=1  AND dataset='{dataset}'"
#      10     f" AND ({algo_filter})"
#      11     " GROUP BY dataset, threads, ratio, algo"
#      12     " ORDER BY ratio, threads"
#      13 ).df()
#      14 rows = rows.pivot(index='ratio', values='v', columns='algo')
#      15 print(rows[algos].to_markdown())
#
# BinderException: Binder Error: Referenced column "threads" not found in FROM clause!
# Candidate bindings: "df.dataset"
